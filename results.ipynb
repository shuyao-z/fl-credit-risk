# %%
import matplotlib.pyplot as plt

# %%
D1_MLP = [0.0130, 0.0136, 0.0441, 0.0223, 0.0301, 0.0486, 0.0316, 0.0512, 0.0817, 0.0584, 0.0805, 0.0991]
D1_MLP_MSE = [0.159084484,0.269320787,0.4121298,0.203710061,0.327044361,0.398533486,0.319661018,0.465414516,0.496135444,0.458820646,0.541942456,0.596524489]
D1_LSTM = [0.0058,0.0162,0.0183,0.0176,0.0179,0.0291,0.0168,0.0404,0.0628,0.0402,0.0641,0.3358]
D1_LSTM_MSE =[0.441895218,0.711590043,0.71679253,0.569088405,0.734469335,0.758152316,0.620023145,0.798412876,0.816568091,0.619437153,0.775295802,0.917002822]
D1_XGB =[0.0206,0.0469,0.0734,0.0420,0.0682,0.0989,0.0681,0.0904,0.1405,0.0666,0.1226,0.2116]
D1_XGB_MSE =[0.365415336,0.427777571,0.519578591,0.396470336,0.519671785,0.629749056,0.477494576,0.551664862,0.741820125,0.535444466,0.710545049,0.790878992]

D2_MLP = [0.0061,0.0075,0.0165,0.0072,0.0182,0.0449,0.0121,0.0383,0.0835,0.0349,0.0805,0.1338]
D2_LSTM = [0.0064,0.0107,0.0403,0.0159,0.0366,0.1017,0.0349,0.0997,0.3229,0.0956,0.3074,0.5022]
D2_XGB = [0.0030,0.0050,0.0169,0.0021,0.0107,0.0171,0.0010,0.0190,0.0404,0.0056,0.0337,0.0570]

D3_MLP = [0.0015,0.0030,0.0064,0.0031,0.0070,0.0143,0.0055,0.0204,0.0302,0.0131,0.0356,0.0383]
D3_XGB= [0.0037,0.0052,0.0115,0.0038,0.0071,0.0147,0.0063,0.0175,0.0295,0.0100,0.0365,0.0559]

# %%
from matplotlib.ticker import FuncFormatter
import numpy as np
import matplotlib.pyplot as plt

def plot_subplot(ax, D1_MLP):
    labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

    bar_width = 0.6  # Width of each bar
    gap_width = 0.2  # Width of the gap between groups of bars

    x_positions = np.arange(len(labels))
    group_colors =  ['tab:red', 'tab:cyan','tab:orange','tab:green']

    for i in range(0, len(D1_MLP), 3):
        if i == 0:
            label = '2 Clients'
            colour = 'tab:red'
        if i == 3:
            label = '3 Clients'
            colour = 'tab:cyan'
        if i == 6:
            label = '5 Clients'
            colour = 'tab:orange'
        if i ==9:
            label = '10 Clients'
            colour = 'tab:green'
        ax.bar(x_positions[i:i + 3], D1_MLP[i:i + 3], width=bar_width, label=label, color=colour)

    # Set the x-axis labels
    ax.set_xticks(x_positions)
    ax.set_xticklabels(labels)

    # Add labels and title
    plt.xlabel('Data Distribution')
    plt.ylabel('Performance Improvement')
    plt.xticks(rotation='vertical')

    # Function to format y-axis as percentages
    def percentage_formatter(x, pos):
        return f'{100 * x:.1f}%'

    # Apply percentage formatting to the y-axis
    ax.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))
    ax.legend()

# %%
# Create a figure with a 3x4 grid of subplots
fig = plt.figure(figsize=(20, 16))

# Create the first subplot (3, 4) - Top left
plt = plt.subplot(3, 4, 1)
plt.set_title('(1) Dataset 1 - MLP - MSE')
plot_subplot(ax1, D1_MLP_MSE)
ax2 = plt.subplot(3, 4, 2)
ax2.set_title('(2) Dataset 1 - MLP - AUC')
plot_subplot(ax2, D1_MLP)

ax3 = plt.subplot(3, 4, 3)
ax3.set_title('(3) Dataset 2 - MLP - AUC')
plot_subplot(ax3, D2_MLP)

ax3 = plt.subplot(3, 4, 4)
ax3.set_title('(4) Dataset 3 - MLP - AUC')
plot_subplot(ax3, D3_MLP)

ax5 = plt.subplot(3, 4, 5)
ax5.set_title('(5) Dataset 1 - XGB - MSE')
ax5.set_ylim(0.2, 0.8)
plot_subplot(ax5, D1_XGB_MSE)

ax6 = plt.subplot(3, 4, 6)
ax6.set_title('(6) Dataset 1 - XGB - AUC')
plot_subplot(ax6, D1_XGB)

ax7 = plt.subplot(3, 4, 7)
ax7.set_title('(7) Dataset 2 - XGB - AUC')
plot_subplot(ax7, D2_XGB)

ax8 = plt.subplot(3, 4, 8)
ax8.set_title('(8) Dataset 3 - XGB - AUC')
plot_subplot(ax8, D3_XGB)

ax9 = plt.subplot(3, 4, 9)
ax9.set_title('(9) Dataset 1 - LSTM - MSE')
ax9.set_ylim(0.2, 1)
plot_subplot(ax9, D1_LSTM_MSE)

ax10 = plt.subplot(3, 4, 10)
ax10.set_title('(10) Dataset 1 - LSTM - AUC')
plot_subplot(ax10, D1_LSTM)

ax11 = plt.subplot(3, 4, 11)
ax11.set_title('(11) Dataset 2 - LSTM - AUC')
plot_subplot(ax11, D2_LSTM)

plt.tight_layout()
plt.show()

# %%
#plt.figure(figsize=(10, 6))
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
plt.plot(labels, D1_MLP, label='Dataset 1 MLP (AUC)')
plt.plot(labels, D1_MLP_MSE, label='Dataset 1 MLP (MSE)',linestyle='dashed')
plt.plot(labels, D1_XGB, label='Dataset 1 XGBoost (AUC)')
plt.plot(labels, D1_XGB_MSE, label='Dataset 1 XGBoost (MSE)',linestyle='dashed')
plt.plot(labels, D1_LSTM, label='Dataset 1 LSTM (AUC)')
plt.plot(labels, D1_LSTM_MSE, label='Dataset 1 LSTM (MSE)',linestyle='dashed')
plt.plot(labels, D2_MLP, label='Dataset 2 MLP (AUC)')
plt.plot(labels, D2_XGB, label='Dataset 2 XGBoost (AUC)')
plt.plot(labels, D2_LSTM, label='Dataset 2 LSTM (AUC)')
plt.plot(labels, D3_MLP, label='Dataset 3 MLP (AUC)')
plt.plot(labels, D3_XGB, label='Dataset 3 XGBoost (AUC)')


plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement')
#plt.title('Dateset 1 MLP')
plt.legend(fontsize=6,ncol=3)
plt.xticks(rotation='vertical')
plt.ylim(0, 1)
plt.show()

# %%
#plt.figure(figsize=(10, 6))
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]


plt.plot(labels, D1_MLP, label='Dataset 1 MLP')
plt.plot(labels, D1_XGB, label='Dataset 1 XGBoost')
plt.plot(labels, D1_LSTM, label='Dataset 1 LSTM')
plt.plot(labels, D2_MLP, label='Dataset 2 MLP')
plt.plot(labels, D2_XGB, label='Dataset 2 XGBoost')
plt.plot(labels, D2_LSTM, label='Dataset 2 LSTM')
plt.plot(labels, D3_MLP, label='Dataset 3 MLP')
plt.plot(labels, D3_XGB, label='Dataset 3 XGBoost')

plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement (AUC)')
#plt.title('Dateset 1 MLP')
plt.legend(fontsize=8,ncol=3)
plt.xticks(rotation='vertical')
plt.ylim(0, 0.6)
plt.show()

# %%
#plt.figure(figsize=(10, 6))
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, D1_MLP_MSE, label='Dataset 1 MLP')

plt.plot(labels, D1_XGB_MSE, label='Dataset 1 XGBoost')

plt.plot(labels, D1_LSTM_MSE, label='Dataset 1 LSTM')


plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement (MSE)')
#plt.title('Dateset 1 MLP')
plt.legend(fontsize=8,loc='upper left')
plt.xticks(rotation='vertical')
#plt.ylim(0, 1)
plt.show()

# %%
plt.figure(figsize=(8, 6))

def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, D1_MLP, label='Dataset 1 MLP')
plt.plot(labels, D1_XGB, label='Dataset 1 XGBoost')
plt.plot(labels, D1_LSTM, label='Dataset 1 LSTM')
plt.plot(labels, D2_MLP, label='Dataset 2 MLP')
plt.plot(labels, D2_XGB, label='Dataset 2 XGBoost')
plt.plot(labels, D2_LSTM, label='Dataset 2 LSTM')
plt.plot(labels, D3_MLP, label='Dataset 3 MLP')
plt.plot(labels, D3_XGB, label='Dataset 3 XGBoost')
avr_auc =[0.0075125, 0.0135125, 0.028425 , 0.01425, 0.024475 , 0.0461625 ,0.0220375, 0.0471125, 0.0989375, 0.04055, 0.0951125, 0.1792125]
plt.plot(labels, avr_auc, label='Average', linestyle='dashed')
plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement (AUC)')

plt.legend(ncol=3)
plt.xticks(rotation='vertical')
plt.ylim(0, 0.6)

plt.show()

# %%
import numpy as np

# Create a 2D NumPy array from the lists
data = np.array([D1_MLP_MSE,D1_LSTM_MSE,D1_XGB_MSE])
data_auc = np.array([D1_MLP, D1_XGB, D1_LSTM,D2_MLP, D2_XGB,D2_LSTM,D3_MLP, D3_XGB,])
# Calculate the column averages
avr_mse = np.mean(data, axis=0)
avr_auc = np.mean(data_auc, axis=0)
# Print the column averages
print(avr_auc)
# Out:
# [0.0075125 0.0135125 0.028425  0.01425   0.024475  0.0461625 0.0220375
#  0.0471125 0.0989375 0.04055   0.0951125 0.1792125]

# %%
D1_MLP_MSE_dominant = [0.159084484,0.111299397,-0.019087425,0.203710061,0.048701323,-0.121520572,0.319661018,0.056088382,-0.11320969,0.458820646,0.031972766,-0.044932169]
D1_MLP_AUC_dominant = [0.012991678,0.007662615,-0.014946673,0.022289662,0.012272232,-0.017314237,0.031648862,0.003923362,-0.006361041,0.058362207,-0.007211839,-0.013106669]

D1_LSTM_MSE_dominant = [0.441895218,0.26841045,0.173153004,0.569088405,0.289095271,0.235575259,0.620023145,0.297166726,0.158711378,0.619437153,0.188768475,0.201591394]
D1_LSTM_AUC_dominant = [0.005790125,0.013011484,0.00452859,0.017563431,0.008440382,0.002451791,0.016826372,0.014146676,0.002300029,0.040204755,0.008315942,0.008225804]

D1_XGB_MSE_dominant = [0.365415336,0.288481923,0.115898232,0.396470336,0.210547103,0.159366577,0.477494576,0.031213702,0.02861711,0.535444466,0.060502757,-0.1351215]
D1_XGB_AUC_dominant = [0.020648892,0.018764613,0.001133038,0.042019784,0.020596841,0.000431357,0.068062909,0.006170129,-0.018349142,0.066627894,-0.023517685,-0.023406893]

D2_MLP_dominant =[0.0061,0.0029,0.0008,0.0072,0.0029,0.0016,0.0121,0.0007,-0.0013,0.0349,-0.0002,0.0012]
D2_LSTM_dominant = [0.006360,0.005094,0.001774,0.015922,0.003495,-0.000863,0.034890,0.002867,0.000460,0.095603,0.000679,0.000028]
D2_XGB_dominant =[0.002952,0.002707,0.001682,0.002066,-0.001899,-0.013431,0.001042,-0.010484,-0.020019,0.005558,-0.024498,-0.026460]

D3_MLP_dominant = [0.0015,0.0014,0.00002,0.0031,0.0015,0.0015,0.0055,0.0028,0.0019,0.0131,0.0022,0.0041]
D3_XGB_dominant = [0.003651,0.002185,0.001117,0.003791,-0.003149,-0.006103,0.006321,-0.002962,-0.012695,0.010039,-0.005506,-0.003178]

# %%
#plt.figure(figsize=(10, 6))
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
plt.plot(labels, D1_MLP_AUC_dominant, label='Dataset 1 MLP (AUC)')
plt.plot(labels, D1_MLP_MSE_dominant, label='Dataset 1 MLP (MSE)',linestyle='dashed')
plt.plot(labels, D1_XGB_AUC_dominant, label='Dataset 1 XGBoost (AUC)')
plt.plot(labels, D1_XGB_MSE_dominant, label='Dataset 1 XGBoost (MSE)',linestyle='dashed')
plt.plot(labels, D1_LSTM_AUC_dominant, label='Dataset 1 LSTM (AUC)')
plt.plot(labels, D1_LSTM_MSE_dominant, label='Dataset 1 LSTM (MSE)',linestyle='dashed')
plt.plot(labels, D2_MLP_dominant, label='Dataset 2 MLP (AUC)')
plt.plot(labels, D2_XGB_dominant, label='Dataset 2 XGBoost (AUC)')
plt.plot(labels, D2_LSTM_dominant, label='Dataset 2 LSTM (AUC)')
plt.plot(labels, D3_MLP_dominant, label='Dataset 3 MLP (AUC)')
plt.plot(labels, D3_XGB_dominant, label='Dataset 3 XGBoost (AUC)')


plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement')
#plt.title('Dateset 1 MLP')
plt.legend(fontsize=6,ncol=3)
plt.xticks(rotation='vertical')
plt.ylim(-0.2, 0.8)
plt.show()

# %%
#plt.figure(figsize=(10, 6))
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
plt.plot(labels, D1_MLP_AUC_dominant, label='Dataset 1 MLP')
#plt.plot(labels, D1_MLP_MSE_dominant, label='Dataset 1 MLP (MSE)',linestyle='dashed')
plt.plot(labels, D1_XGB_AUC_dominant, label='Dataset 1 XGBoost')
#plt.plot(labels, D1_XGB_MSE_dominant, label='Dataset 1 XGBoost (MSE)',linestyle='dashed')
plt.plot(labels, D1_LSTM_AUC_dominant, label='Dataset 1 LSTM')
#plt.plot(labels, D1_LSTM_MSE_dominant, label='Dataset 1 LSTM (MSE)',linestyle='dashed')
plt.plot(labels, D2_MLP_dominant, label='Dataset 2 MLP')
plt.plot(labels, D2_XGB_dominant, label='Dataset 2 XGBoost')
plt.plot(labels, D2_LSTM_dominant, label='Dataset 2 LSTM')
plt.plot(labels, D3_MLP_dominant, label='Dataset 3 MLP')
plt.plot(labels, D3_XGB_dominant, label='Dataset 3 XGBoost')


plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement (AUC)')
#plt.title('Dateset 1 MLP')
plt.legend(fontsize=6,ncol=3)
plt.xticks(rotation='vertical')
#plt.ylim(-0.2, 0.8)
plt.show()

# %%
#plt.figure(figsize=(10, 6))
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, D1_MLP_MSE_dominant, label='Dataset 1 MLP')

plt.plot(labels, D1_XGB_MSE_dominant, label='Dataset 1 XGBoost')

plt.plot(labels, D1_LSTM_MSE_dominant, label='Dataset 1 LSTM')

plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement (MSE)')
#plt.title('Dateset 1 MLP')
plt.legend(fontsize=8, loc='upper left')
plt.xticks(rotation='vertical')
plt.ylim(-0.2, 0.8)
plt.show()

# %%
plt.figure(figsize=(8, 6))

def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, D1_MLP_AUC_dominant, label='Dataset 1 MLP')
plt.plot(labels, D1_XGB_AUC_dominant, label='Dataset 1 XGBoost')
plt.plot(labels, D1_LSTM_AUC_dominant, label='Dataset 1 LSTM')
plt.plot(labels, D2_MLP_dominant, label='Dataset 2 MLP')
plt.plot(labels, D2_XGB_dominant, label='Dataset 2 XGBoost')
plt.plot(labels, D2_LSTM_dominant, label='Dataset 2 LSTM')
plt.plot(labels, D3_MLP_dominant, label='Dataset 3 MLP')
plt.plot(labels, D3_XGB_dominant, label='Dataset 3 XGBoost')

avr_auc =[ 0.00749921,  0.00671559, -0.00048651 , 0.01424398,  0.00551956, -0.00396601,
  0.02204889,  0.00214515, -0.00675802,  0.04054936 ,-0.00621732 ,-0.00657472]
plt.plot(labels, avr_auc, label='Average', linestyle='dashed')

plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement (AUC)')

plt.legend(ncol=3)
plt.xticks(rotation='vertical')
plt.ylim(-0.03, 0.12)


plt.show()

# %%
import numpy as np

# Create a 2D NumPy array from the lists
data = np.array([D1_MLP_MSE_dominant,D1_LSTM_MSE_dominant,D1_XGB_MSE_dominant])
data_auc = np.array([D1_MLP_AUC_dominant,D1_XGB_AUC_dominant,D1_LSTM_AUC_dominant,D2_MLP_dominant,D2_XGB_dominant,D2_LSTM_dominant,D3_MLP_dominant,D3_XGB_dominant, ])
# Calculate the column averages
avr_mse = np.mean(data, axis=0)
avr_auc = np.mean(data_auc, axis=0)
# Print the column averages
print(avr_mse)
print(avr_auc)
# Out:
# [0.32213168 0.22273059 0.08998794 0.38975627 0.18278123 0.09114042
#  0.47239291 0.12815627 0.02470627 0.53790076 0.093748   0.00717924]
# [ 0.00749921  0.00671559 -0.00048651  0.01424398  0.00551956 -0.00396601
#   0.02204889  0.00214515 -0.00675802  0.04054936 -0.00621732 -0.00657472]

# %%
def plot_subplot_dominant(ax, D1_MLP):
    labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

    bar_width = 0.6  # Width of each bar
    gap_width = 0.2  # Width of the gap between groups of bars

    x_positions = np.arange(len(labels))
    group_colors =  ['tab:red', 'tab:cyan','tab:orange','tab:green']

    for i in range(0, len(D1_MLP), 3):
        if i == 0:
            label = '2 Clients'
            colour = 'tab:red'
        if i == 3:
            label = '3 Clients'
            colour = 'tab:cyan'
        if i == 6:
            label = '5 Clients'
            colour = 'tab:orange'
        if i == 9:
            label = '10 Clients'
            colour = 'tab:green'

        # Plot the bars for each group, including positive and negative values
        ax.bar(x_positions[i:i + 3], D1_MLP[i:i + 3], width=bar_width, label=label, color=colour)

    # Set the x-axis labels
    ax.set_xticks(x_positions)
    ax.set_xticklabels(labels)

    # Add labels and title
    ax.set_xlabel('Data Distribution')
    ax.set_ylabel('Performance Improvement')
    ax.set_xticklabels(labels, rotation='vertical')

    # Function to format y-axis as percentages
    def percentage_formatter(x, pos):
        return f'{100 * x:.1f}%'

    # Set the y-axis to include negative values
    ax.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))
    ax.legend(loc='upper left')

def modify_subplot(ax, D1_MLP):
    min_value = min(D1_MLP) * 1.1
    max_value = max(D1_MLP) * 1.1
    ax.set_ylim(min_value, max_value)
    ax.legend(loc='upper left')

# %%
fig = plt.figure(figsize=(20, 16))

ax1 = plt.subplot(3, 4, 1)
ax1.set_title('(1) Dataset 1 - MLP - MSE')
plot_subplot(ax1, D1_MLP_MSE_dominant)
ax2 = plt.subplot(3, 4, 2)
ax2.set_title('(2) Dataset 1 - MLP - AUC')
plot_subplot(ax2, D1_MLP_AUC_dominant)

ax3 = plt.subplot(3, 4, 3)
ax3.set_title('(3) Dataset 2 - MLP - AUC')
plot_subplot(ax3, D2_MLP_dominant)

ax4 = plt.subplot(3, 4, 4)
ax4.set_title('(4) Dataset 3 - MLP - AUC')
plot_subplot_dominant(ax4, D3_MLP_dominant)

ax5 = plt.subplot(3, 4, 5)
ax5.set_title('(5) Dataset 1 - XGB - MSE')
plot_subplot(ax5, D1_XGB_MSE_dominant)

ax6 = plt.subplot(3, 4, 6)
ax6.set_title('(6) Dataset 1 - XGB - AUC')
plot_subplot(ax6, D1_XGB_AUC_dominant)

ax7 = plt.subplot(3, 4, 7)
ax7.set_title('(7) Dataset 2 - XGB - AUC')
plot_subplot(ax7, D2_XGB_dominant)

ax8 = plt.subplot(3, 4, 8)
ax8.set_title('(8) Dataset 3 - XGB - AUC')
plot_subplot(ax8, D3_XGB_dominant)

ax9 = plt.subplot(3, 4, 9)
ax9.set_title('(9) Dataset 1 - LSTM - MSE')
plot_subplot(ax9, D1_LSTM_MSE_dominant)

ax10 = plt.subplot(3, 4, 10)
ax10.set_title('(10) Dataset 1 - LSTM - AUC')
plot_subplot(ax10, D1_LSTM_AUC_dominant)

ax11 = plt.subplot(3, 4, 11)
ax11.set_title('(11) Dataset 2 - LSTM - AUC')
plot_subplot(ax11, D2_LSTM_dominant)

modify_subplot(ax1, D1_MLP_MSE_dominant)
modify_subplot(ax5, D1_XGB_MSE_dominant)
ax9.legend(loc='upper left')
ax9.set_ylim(0.1, 0.7)

plt.tight_layout()
plt.show()

# %%
def plot_line(ax, non_dominant, dominant_2, non_dominant_2, fl_2, dominant_3, non_dominant_3, fl_3,
               dominant_5, non_dominant_5, fl_5, dominant_10, non_dominant_10, fl_10):
    classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]


    local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

    locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

    auc_fl = fl_2 + fl_3 + fl_5 + fl_10
    auc_central = 12 * [central]

    plt.figure(figsize=(10, 6))

    ax.plot(classes, local_dominant, label='Local Dominant')
    ax.plot(classes, locan_non_dominant, label='Local Non-Dominant')
    ax.plot(classes, auc_fl, label='Federated')
    ax.plot(classes, auc_central, label='Centralised')

    ax.set_xlabel('Data Distribution')
    ax.set_ylabel('AUC')
    #plt.title('Dateset 1 MLP')
    ax.legend()
    #ax.set_xticks()
    ax.set_xticklabels(classes,rotation='vertical')
    #plt.show()

# %%
central_d1_mlp = 0.9066
dominant_2_d1_mlp = [0.8770, 0.8856, 0.8979]
non_dominant_2_d1_mlp = [0.8770, 0.8804,0.8471,]
fl_2_d1_mlp = [0.8884, 0.8924,0.8844,]

dominant_3_d1_mlp = [0.8673, 0.8789, 0.8986]
non_dominant_3_d1_mlp = [0.8673, 0.8637,0.8421,]
fl_3_d1_mlp = [0.8866, 0.8897,0.8831,]

dominant_5_d1_mlp = [0.8544, 0.8777, 0.8944]
non_dominant_5_d1_mlp = [0.8544, 0.8383,0.8216,]
fl_5_d1_mlp = [0.8814, 0.8812,0.8887,]

dominant_10_d1_mlp = [0.8270, 0.8858, 0.8926]
non_dominant_10_d1_mlp = [0.8270, 0.8139,0.8015,]
fl_10_d1_mlp = [0.8753, 0.8794,0.8809,]

central_d1_lstm = 0.9714
dominant_2_d1_lstm = [0.9713, 0.9664, 0.9756]
non_dominant_2_d1_lstm = [0.9713, 0.9634,0.9625,]
fl_2_d1_lstm = [0.9769, 0.9790, 0.9801]

dominant_3_d1_lstm = [0.9600, 0.9656, 0.9735]
non_dominant_3_d1_lstm = [0.9600, 0.9566,0.9483,]
fl_3_d1_lstm = [0.9769, 0.9737,0.9759,]

dominant_5_d1_lstm = [0.9510, 0.9631, 0.9747]
non_dominant_5_d1_lstm = [0.9510, 0.9389,0.9192,]
fl_5_d1_lstm = [0.9758, 0.9767,0.9769,]

dominant_10_d1_lstm = [0.9393, 0.9680, 0.9710]
non_dominant_10_d1_lstm = [0.9393, 0.9173,0.7329,]
fl_10_d1_lstm = [0.9770, 0.9760,0.9790,]


central_d1_xgb = 0.9066
dominant_2_d1_xgb = [0.8791, 0.8856, 0.8979]
non_dominant_2_d1_xgb = [0.8749, 0.8804,0.8471,]
fl_2_d1_xgb = [0.8884, 0.8924,0.8844,]

dominant_3_d1_xgb = [0.8620, 0.8789, 0.8986]
non_dominant_3_d1_xgb = [0.8726, 0.8637,0.8421,]
fl_3_d1_xgb = [0.8866, 0.8897,0.8831,]

dominant_5_d1_xgb = [0.8532, 0.8777, 0.8944]
non_dominant_5_d1_xgb = [0.8555, 0.8383,0.8216,]
fl_5_d1_xgb = [0.8814, 0.8812,0.8887,]

dominant_10_d1_xgb = [0.8172, 0.8858, 0.8926]
non_dominant_10_d1_xgb = [0.8368, 0.8139,0.8015,]
fl_10_d1_xgb = [0.8753, 0.8794,0.8809,]

# %%
fig = plt.figure(figsize=(20, 16))

ax1 = plt.subplot(3, 3, 1)
ax1.set_title('(1) Dataset 1 - MLP')
plot_line(ax1, central_d1_mlp, dominant_2_d1_mlp, non_dominant_2_d1_mlp, fl_2_d1_mlp, dominant_3_d1_mlp, non_dominant_3_d1_mlp, fl_3_d1_mlp,
               dominant_5_d1_mlp, non_dominant_5_d1_mlp, fl_5_d1_mlp, dominant_10_d1_mlp, non_dominant_10_d1_mlp, fl_10_d1_mlp)
# ax2 = plt.subplot(3, 4, 2)
# ax2.set_title('(2) Dataset 1 - MLP - AUC')
# plot_subplot(ax2, D1_MLP_AUC_dominant)

# ax3 = plt.subplot(3, 4, 3)
# ax3.set_title('(3) Dataset 2 - MLP - AUC')
# plot_subplot(ax3, D2_MLP_dominant)
#
# ax4 = plt.subplot(3, 4, 4)
# ax4.set_title('(4) Dataset 3 - MLP - AUC')
# plot_subplot_dominant(ax4, D3_MLP_dominant)
#
ax4 = plt.subplot(3, 3, 4)
ax4.set_title('(4) Dataset 1 - XGB - MSE')
plot_line(ax4, central_d1_lstm, dominant_2_d1_lstm, non_dominant_2_d1_lstm, fl_2_d1_lstm, dominant_3_d1_lstm, non_dominant_3_d1_lstm, fl_3_d1_lstm,
               dominant_5_d1_lstm, non_dominant_5_d1_lstm, fl_5_d1_lstm, dominant_10_d1_lstm, non_dominant_10_d1_lstm, fl_10_d1_lstm)

# ax6 = plt.subplot(3, 4, 6)
# ax6.set_title('(6) Dataset 1 - XGB - AUC')
# plot_subplot(ax6, D1_XGB_AUC_dominant)
#
# ax7 = plt.subplot(3, 4, 7)
# ax7.set_title('(7) Dataset 2 - XGB - AUC')
# plot_subplot(ax7, D2_XGB_dominant)
#
# ax8 = plt.subplot(3, 4, 8)
# ax8.set_title('(8) Dataset 3 - XGB - AUC')
# plot_subplot(ax8, D3_XGB_dominant)
#
ax7 = plt.subplot(3, 3, 7)
ax7.set_title('(7) Dataset 1 - LSTM')
plot_line(ax7, central_d1_lstm, dominant_2_d1_lstm, non_dominant_2_d1_lstm, fl_2_d1_lstm, dominant_3_d1_lstm, non_dominant_3_d1_lstm, fl_3_d1_lstm,
               dominant_5_d1_lstm, non_dominant_5_d1_lstm, fl_5_d1_lstm, dominant_10_d1_lstm, non_dominant_10_d1_lstm, fl_10_d1_lstm)
#
# ax10 = plt.subplot(3, 4, 10)
# ax10.set_title('(10) Dataset 1 - LSTM - AUC')
# plot_subplot(ax10, D1_LSTM_AUC_dominant)
#
# ax11 = plt.subplot(3, 4, 11)
# ax11.set_title('(11) Dataset 2 - LSTM - AUC')
# plot_subplot(ax11, D2_LSTM_dominant)
#
# modify_subplot(ax1, D1_MLP_MSE_dominant)
# modify_subplot(ax5, D1_XGB_MSE_dominant)
# ax9.legend(loc='upper left')
# ax9.set_ylim(0.1, 0.7)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Shuyao\AppData\Local\Temp\ipykernel_33600\713244718.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(classes,rotation='vertical')

# %%
central_d1_mlp = [0.9066]
dominant_d1_mlp = [0.8770, 0.8856, 0.8979,0.8673, 0.8789, 0.8986,0.8544, 0.8777, 0.8944,0.8270, 0.8858, 0.8926]
non_dominant_d1_mlp = [0.8770, 0.8804,0.8471,0.8673, 0.8637,0.8421,0.8544, 0.8383,0.8216,0.8270, 0.8139,0.8015,]
fl_d1_mlp = [0.8884, 0.8924,0.8844,0.8866, 0.8897,0.8831,0.8814, 0.8812,0.8887,0.8753, 0.8794,0.8809,]

central_d1_lstm = [0.9714]
dominant_d1_lstm = [0.9713, 0.9664, 0.9756,0.9600, 0.9656, 0.9735,0.9510, 0.9631, 0.9747,0.9393, 0.9680, 0.9710]
non_dominant_d1_lstm = [0.9713, 0.9634,0.9625,0.9600, 0.9566,0.9483,0.9510, 0.9389,0.9192,0.9393, 0.9173,0.7329,]
fl_d1_lstm = [0.9769, 0.9790, 0.9801,0.9769, 0.9737,0.9759,0.9758, 0.9767,0.9769,0.9770, 0.9760,0.9790,]

central_d1_xgb = [0.9154]
dominant_d1_xgb =[0.8902, 0.8999, 0.9092, 0.8702, 0.8912, 0.908, 0.8501, 0.8962, 0.9076, 0.8249, 0.9025, 0.9109]
non_dominant_d1_xgb =[0.8902, 0.8757, 0.848, 0.8702, 0.8515, 0.8266, 0.8501, 0.827, 0.7812, 0.8249, 0.785, 0.7342]
fl_d1_xgb =[0.8884, 0.8924, 0.8844, 0.9068, 0.9095, 0.9084, 0.9079, 0.9018, 0.8909, 0.8799, 0.8813, 0.8896]

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, central_d1_mlp*12, label='Centralised - MLP', color='tab:blue')
plt.plot(labels, dominant_d1_mlp, label='Local Dominant - MLP', color='tab:green')
plt.plot(labels, non_dominant_d1_mlp, label='Local Non-Dominant - MLP', color='tab:red')
plt.plot(labels, fl_d1_mlp, label='Federated - MLP', color='tab:orange')

plt.plot(labels, central_d1_lstm*12, label='Centralised - LSTM',linestyle='dashed', color='tab:blue')
plt.plot(labels, dominant_d1_lstm, label='Local Dominant - LSTM',linestyle='dashed', color='tab:green')
plt.plot(labels, non_dominant_d1_lstm, label='Local Non-Dominant - LSTM', linestyle='dashed', color='tab:red')
plt.plot(labels, fl_d1_lstm, label='Federated - LSTM', color='tab:orange', linestyle='dashed')

plt.plot(labels, central_d1_xgb*12, label='Centralised - XGBoost', linestyle='dotted', color='tab:blue')
plt.plot(labels, dominant_d1_xgb, label='Local Dominant - XGBoost', linestyle='dotted', color='tab:green')
plt.plot(labels, non_dominant_d1_xgb, label='Local Non-Dominant - XGBoost', linestyle='dotted', color='tab:red')
plt.plot(labels, fl_d1_xgb, label='Federated - XGBoost', color='tab:orange', linestyle='dotted')

plt.xlabel('Data Distribution')
plt.ylabel('AUC')

plt.legend(fontsize=6, ncol=3, loc='upper left')
plt.xticks(rotation='vertical')
plt.ylim(0.7, 1.05)
plt.yticks([0.7, 1])
plt.show()

# %%
central_d1_mlp_MSE = [1.9765]
dominant_d1_mlp_MSE = [2.5490,2.2260,2.0689,2.7398,2.2366,2.0238,3.2373,2.2894,2.0674,4.0626,2.3467,2.0685]
non_dominant_d1_mlp_MSE =[2.5490,2.7074,3.5865,2.7398,3.1617,3.7736,3.2373,4.0424,4.5676,4.0626,4.9593,5.3570]

fl_d1_mlp_MSE =[2.1435,1.9783,2.1084,2.1817,2.1277,2.2697,2.2024,2.1610,2.3014,2.1986,2.2716,2.1614]

central_d1_lstm_MSE = [0.8609]
dominant_d1_lstm_MSE =[1.0064,0.7527,0.6672,1.3035,0.8137,0.7450,1.5019,0.8259,0.6848,1.7470,0.7568,0.6882]
non_dominant_d1_lstm_MSE =[1.0064,1.9092,1.9480,1.3035,2.1785,2.3546,1.5019,2.8796,3.1410,1.7470,2.7321,6.6200]
fl_d1_lstm_MSE =[0.5617,0.5506,0.5517,0.5617,0.5784,0.5695,0.5707,0.5805,0.5762,0.6648,0.6139,0.5494,]

central_d1_xgb_MSE = [1.9109]
dominant_d1_xgb_MSE =[2.6536,2.4610,2.1033,3.1959,2.3660,2.1461,4.0029,2.3401,2.1170,5.0851,2.3741,2.0355]
non_dominant_d1_xgb_MSE =[2.6536,3.0601,3.8706,3.1959,3.8887,4.8726,4.0029,5.0567,7.9649,5.0851,7.7057,11.0488]
fl_d1_xgb_MSE =[1.6839,1.7511,1.8595,1.9288,1.8678,1.8041,2.0915,2.2671,2.0564,2.3623,2.2304,2.3105,]

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, central_d1_mlp_MSE*12, label='Centralised - MLP', color='tab:blue')
plt.plot(labels, dominant_d1_mlp_MSE, label='Local Dominant - MLP', color='tab:green')
plt.plot(labels, non_dominant_d1_mlp_MSE, label='Local Non-Dominant - MLP', color='tab:red')
plt.plot(labels, fl_d1_mlp_MSE, label='Federated - MLP', color='tab:orange')

plt.plot(labels, central_d1_lstm_MSE*12, label='Centralised - LSTM',linestyle='dashed', color='tab:blue')
plt.plot(labels, dominant_d1_lstm_MSE, label='Local Dominant - LSTM',linestyle='dashed', color='tab:green')
plt.plot(labels, non_dominant_d1_lstm_MSE, label='Local Non-Dominant - LSTM', linestyle='dashed', color='tab:red')
plt.plot(labels, fl_d1_lstm_MSE, label='Federated - LSTM', color='tab:orange', linestyle='dashed')

plt.plot(labels, central_d1_xgb_MSE*12, label='Centralised - XGBoost', linestyle='dotted', color='tab:blue')
plt.plot(labels, dominant_d1_xgb_MSE, label='Local Dominant - XGBoost', linestyle='dotted', color='tab:green')
plt.plot(labels, non_dominant_d1_xgb_MSE, label='Local Non-Dominant - XGBoost', linestyle='dotted', color='tab:red')
plt.plot(labels, fl_d1_xgb_MSE, label='Federated - XGBoost', color='tab:orange', linestyle='dotted')

plt.xlabel('Data Distribution')
plt.ylabel('MSE')

plt.legend(fontsize=6, ncol=3, loc='upper left')
plt.xticks(rotation='vertical')
plt.ylim(0.0, 14)
#plt.yticks([0, 12,2])
plt.show()

# %%
central_d2_mlp = [0.7577]
dominant_d2_mlp = [0.754, 0.7557, 0.7566, 0.7517, 0.7557, 0.7571, 0.7459, 0.7554, 0.7574, 0.727, 0.7559, 0.7565]
non_dominant_d2_mlp = [0.754, 0.7522, 0.7449, 0.7517, 0.7443, 0.7257, 0.7459, 0.728, 0.6981, 0.727, 0.6995, 0.6681]
fl_d2_mlp = [0.7586, 0.7579, 0.7572, 0.7571, 0.7579, 0.7583, 0.7549, 0.7559, 0.7564, 0.7524, 0.7558, 0.7575]

central_d2_lstm = [0.7503]
dominant_d2_lstm = [0.7466, 0.7484, 0.7505, 0.7392, 0.7481, 0.7504, 0.7238, 0.7489, 0.7504, 0.6843, 0.7484, 0.7504]
non_dominant_d2_lstm = [0.7466, 0.7442, 0.7227, 0.7392, 0.7242, 0.6805, 0.7238, 0.683, 0.5675, 0.6843, 0.5728, 0.4995]
fl_d2_lstm = [0.7513, 0.7522, 0.7518, 0.751, 0.7508, 0.7498, 0.7491, 0.7511, 0.7507, 0.7494, 0.7489, 0.7504]

central_d2_xgb = [0.7667]
dominant_d2_xgb =[0.7617, 0.7629, 0.7646, 0.7581, 0.7629, 0.7646, 0.7522, 0.7633, 0.765, 0.7413, 0.7633, 0.765]
non_dominant_d2_xgb =[0.7617, 0.7612, 0.7532, 0.7581, 0.7534, 0.7416, 0.7522, 0.7412, 0.7206, 0.7413, 0.7204, 0.7046]
fl_d2_xgb =[0.764, 0.765, 0.7659, 0.7597, 0.7615, 0.7543, 0.753, 0.7553, 0.7497, 0.7454, 0.7446, 0.7448]

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, central_d2_mlp*12, label='Centralised - MLP', color='tab:blue')
plt.plot(labels, dominant_d2_mlp, label='Local Dominant - MLP', color='tab:green')
plt.plot(labels, non_dominant_d2_mlp, label='Local Non-Dominant - MLP', color='tab:red')
plt.plot(labels, fl_d2_mlp, label='Federated - MLP', color='tab:orange')

plt.plot(labels, central_d2_lstm*12, label='Centralised - LSTM',linestyle='dashed', color='tab:blue')
plt.plot(labels, dominant_d2_lstm, label='Local Dominant - LSTM',linestyle='dashed', color='tab:green')
plt.plot(labels, non_dominant_d2_lstm, label='Local Non-Dominant - LSTM', linestyle='dashed', color='tab:red')
plt.plot(labels, fl_d2_lstm, label='Federated - LSTM', color='tab:orange', linestyle='dashed')

plt.plot(labels, central_d2_xgb*12, label='Centralised - XGBoost', linestyle='dotted', color='tab:blue')
plt.plot(labels, dominant_d2_xgb, label='Local Dominant - XGBoost', linestyle='dotted', color='tab:green')
plt.plot(labels, non_dominant_d2_xgb, label='Local Non-Dominant - XGBoost', linestyle='dotted', color='tab:red')
plt.plot(labels, fl_d2_xgb, label='Federated - XGBoost', color='tab:orange', linestyle='dotted')

plt.xlabel('Data Distribution')
plt.ylabel('AUC')

plt.legend(fontsize=6, ncol=3, loc='upper left')
plt.xticks(rotation='vertical')
plt.ylim(0.5, 0.83)
#plt.yticks([0.7, 1])
plt.show()

# %%
central_d3_mlp = [0.8346]
dominant_d3_mlp =[0.8327, 0.833, 0.8342, 0.8311, 0.8325, 0.8337, 0.8285, 0.8319, 0.8334, 0.8214, 0.8325, 0.8307]
non_dominant_d3_mlp =[0.8327, 0.8317, 0.8289, 0.8311, 0.828, 0.8231, 0.8285, 0.817563917, 0.810475185, 0.8214, 0.80570552, 0.80327009]
fl_d3_mlp =[0.8339, 0.8342, 0.8342, 0.8337, 0.8337, 0.835, 0.8331, 0.8343, 0.835, 0.8322, 0.8343, 0.834]


central_d3_xgb = [0.8652]
dominant_d3_xgb =[0.8622, 0.8632, 0.8641, 0.8579, 0.8632, 0.8641, 0.8552, 0.8632, 0.8641, 0.8463, 0.8632, 0.8641]
non_dominant_d3_xgb =[0.8622, 0.8606, 0.8553, 0.8579, 0.8544, 0.8464, 0.8552, 0.8458, 0.8288, 0.8463, 0.8282, 0.8158]
fl_d3_xgb =[0.8653, 0.865, 0.8651, 0.8611, 0.8604, 0.8589, 0.8606, 0.8606, 0.8532, 0.8548, 0.8584, 0.8614]

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, central_d3_mlp*12, label='Centralised - MLP', color='tab:blue')
plt.plot(labels, dominant_d3_mlp, label='Local Dominant - MLP', color='tab:green')
plt.plot(labels, non_dominant_d3_mlp, label='Local Non-Dominant - MLP', color='tab:red')
plt.plot(labels, fl_d3_mlp, label='Federated - MLP', color='tab:orange')

plt.plot(labels, central_d3_xgb*12, label='Centralised - XGBoost', linestyle='dotted', color='tab:blue')
plt.plot(labels, dominant_d3_xgb, label='Local Dominant - XGBoost', linestyle='dotted', color='tab:green')
plt.plot(labels, non_dominant_d3_xgb, label='Local Non-Dominant - XGBoost', linestyle='dotted', color='tab:red')
plt.plot(labels, fl_d3_xgb, label='Federated - XGBoost', color='tab:orange', linestyle='dotted')

plt.xlabel('Data Distribution')
plt.ylabel('AUC')

plt.legend(fontsize=6, ncol=2, loc='upper left')
plt.xticks(rotation='vertical')
plt.ylim(0.8, 0.88)
#plt.yticks([0.7, 1])
plt.show()

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.figure(figsize=(8, 6))

plt.plot(labels, central_d1_mlp*12, label='Centralised - Dataset 1 MLP', color='tab:blue')
plt.plot(labels, fl_d1_mlp, label='Federated - Dataset 1 MLP', color='tab:blue', linestyle='dashed')

plt.plot(labels, central_d2_mlp*12, label='Centralised - Dataset 2 MLP', color='tab:pink')
plt.plot(labels, fl_d2_mlp, label='Federated - Dataset 2 MLP', color='tab:pink', linestyle='dashed')

plt.plot(labels, central_d3_mlp*12, label='Centralised - Dataset 3 MLP', color='tab:red')
plt.plot(labels, fl_d3_mlp, label='Federated - Dataset 3 MLP', color='tab:red', linestyle='dashed')

plt.plot(labels, central_d1_lstm*12, label='Centralised - Dataset 1 LSTM',color='tab:orange')
plt.plot(labels, fl_d1_lstm, label='Federated - Dataset 1 LSTM', color='tab:orange', linestyle='dashed')

plt.plot(labels, central_d2_lstm*12, label='Centralised - Dataset 2 LSTM',color='tab:cyan')
plt.plot(labels, fl_d2_lstm, label='Federated - Dataset 2 LSTM', color='tab:cyan', linestyle='dashed')

plt.plot(labels, central_d1_xgb*12, label='Centralised - Dataset 1 XGBoost', color='tab:green')
plt.plot(labels, fl_d1_xgb, label='Federated - Dataset 1 XGBoost', color='tab:green', linestyle='dashed')

plt.plot(labels, central_d2_xgb*12, label='Centralised - Dataset 2 XGBoost', color='tab:purple')
plt.plot(labels, fl_d2_xgb, label='Federated - Dataset 2 XGBoost', color='tab:purple', linestyle='dashed')

plt.plot(labels, central_d3_xgb*12, label='Centralised - Dataset 3 XGBoost', color='tab:brown')
plt.plot(labels, fl_d3_xgb, label='Federated - Dataset 3 XGBoost', color='tab:brown', linestyle='dashed')

plt.xlabel('Data Distribution')
plt.ylabel('AUC')
plt.legend(fontsize=7, ncol=3, loc='upper left')
plt.xticks(labels, rotation=90)
plt.ylim(0.7, 1.1)
plt.yticks(np.arange(0.7, 1, 0.05))


plt.show()

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
plt.figure(figsize=(8, 6))

plt.plot(labels, central_d1_mlp_MSE*12, label='Centralised - Dataset 1 MLP', color='tab:blue')
plt.plot(labels, fl_d1_mlp_MSE, label='Federated - Dataset 1 MLP', color='tab:blue', linestyle='dashed')

plt.plot(labels, central_d1_lstm_MSE*12, label='Centralised - Dataset 1 LSTM',color='tab:orange')
plt.plot(labels, fl_d1_lstm_MSE, label='Federated - Dataset 1 LSTM', color='tab:orange', linestyle='dashed')

plt.plot(labels, central_d1_xgb_MSE*12, label='Centralised - Dataset 1 XGBoost', color='tab:green')
plt.plot(labels, fl_d1_xgb_MSE, label='Federated - Dataset 1 XGBoost', color='tab:green', linestyle='dashed')

plt.xlabel('Data Distribution')
plt.ylabel('MSE')

plt.legend(ncol=2, loc='upper left')
plt.xticks(rotation='vertical')
plt.ylim(0, 4)
#plt.yticks(np.arange(0.7, 1, 0.05))

plt.show()

# %%
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.plot(labels, D1_MLP_c, label='Dataset 1 MLP')
plt.plot(labels, D1_XGB_c, label='Dataset 1 XGBoost')
plt.plot(labels, D1_LSTM_c, label='Dataset 1 LSTM')
plt.plot(labels, D2_MLP_c, label='Dataset 2 MLP')
plt.plot(labels, D2_XGB_c, label='Dataset 2 XGBoost')
plt.plot(labels, D2_LSTM_c, label='Dataset 2 LSTM')
plt.plot(labels, D3_MLP_c, label='Dataset 3 MLP')
plt.plot(labels, D3_XGB_c, label='Dataset 3 XGBoost')
avr_auc =[-0.00296182, -0.00084522, -0.00269869 ,-0.00511151, -0.00440621,-0.00652431,
 -0.00771862, -0.00745293, -0.00970798, -0.01477505 ,-0.01298727, -0.01031877]
plt.plot(labels, avr_auc, label='Average', linestyle='dashed')
plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement (AUC)')
plt.legend(fontsize=8,ncol=3)
plt.xticks(rotation='vertical')
plt.ylim(-0.04, 0.02)


plt.show()

# %%
import matplotlib.pyplot as plt

# Define your data
x_labels = ["Centralised", "50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
y_labels = ["Dataset 1 MLP", "Dataset 1 XGBoost", "Dataset 1 LSTM", "Dataset 2 MLP", "Dataset 2 XGBoost", "Dataset 2 LSTM", "Dataset 3 MLP", "Dataset 3 XGBoost"]

# Create a figure and axis
#fig, ax = plt.subplots(figsize=(9, 6))
fig, ax = plt.subplots()

# Define spot coordinates using lists for two spots only
spot_x = [x_labels.index("Centralised"),
          x_labels.index("60-40"),
          x_labels.index("80-20"),

          x_labels.index("50-50"),
          x_labels.index("Centralised"),
          x_labels.index("60-40"),

          x_labels.index("80-5-5-5-5"),
          x_labels.index("50-50"),]
spot_y = [y_labels.index("Dataset 1 MLP"),
          y_labels.index("Dataset 1 XGBoost"),
          y_labels.index("Dataset 1 LSTM"),
          y_labels.index("Dataset 2 MLP"),
          y_labels.index("Dataset 2 XGBoost"),
          y_labels.index("Dataset 2 LSTM"),
          y_labels.index("Dataset 3 MLP"),
          y_labels.index("Dataset 3 XGBoost"),]

# Plot the dots
for x, y in zip(spot_x, spot_y):
    # Plot blue spots at the specified intersections
    ax.scatter(x, y, color='tab:blue', s=100)

spot_x_mse = [x_labels.index("Centralised"),
          x_labels.index("60-40"),
          x_labels.index("80-20"),]
spot_y_mse = [y_labels.index("Dataset 1 MLP"),
          y_labels.index("Dataset 1 XGBoost"),
          y_labels.index("Dataset 1 LSTM"),]

# for x, y in zip(spot_x_mse, spot_y_mse):
#     # Plot blue spots at the specified intersections
#     ax.scatter(x, y, color='tab:orange', s=70,marker='^')

# Set axis labels and tick labels
ax.set_xticks(range(len(x_labels)))
ax.set_yticks(range(len(y_labels)))
ax.set_xticklabels(x_labels, rotation=90,fontsize=8)
ax.set_yticklabels(y_labels,fontsize=8)


# Set axis limits
ax.set_xlim(-0.5, len(x_labels) - 2.5)
ax.set_ylim(-0.5, len(y_labels) - 0.5)

# legend_labels = ["AUC", "MSE"]
# legend_markers = [plt.Line2D([0], [0], marker='o', color='w', label='AUC', markersize=10, markerfacecolor='tab:blue'),
#                   plt.Line2D([0], [0], marker='^', color='w', label='MSE', markersize=10, markerfacecolor='tab:orange')]
# ax.legend(handles=legend_markers, labels=legend_labels, loc='lower right')


# Show the plot
plt.grid(False)
plt.xlabel("Data Distribution")
plt.ylabel("Model")
plt.gca().set_aspect('equal', adjustable='box')
plt.tight_layout()
plt.show()

# %%
D1_MLP_c = [-0.020091998,-0.015701423,-0.0244712,-0.022057003,-0.01864852,-0.025985539,-0.027826251,-0.028081839,-0.019771928,-0.034560744,-0.029997827,-0.028345734]
D1_MLP_MSE_c = [-0.084448541,-0.000875263,-0.066707746,-0.103803049,-0.076469339,-0.148321638,-0.11428993,-0.09331686,-0.164371828,-0.112357216,-0.149295269,-0.093535416]

D1_LSTM_c = [0.005684355,0.007785281,0.008916548,0.005662696,0.002384998,0.004623062,0.004590574,0.005512866,0.005684355,0.005801012,0.004762062,0.007866086]
D1_LSTM_MSE_c = [0.347539932,0.360396463,0.359169994,0.34752567,0.328087564,0.338519681,0.337114946,0.325713063,0.330754421,0.227723902,0.286886766,0.361779806]
D1_XGB_c = [-0.007386919,0.001554363,-0.005634855,-0.009397747,-0.00638619,-0.007632007,-0.008113262,-0.014854431,-0.026676269,-0.038740645,-0.037262404,-0.028170479]
D1_XGB_MSE_c = [0.118778344,0.083635323,0.02689141,-0.00937619,0.022532255,0.055904484,-0.094524223,-0.186400629,-0.076133465,-0.236227591,-0.167224204,-0.209138724]

D2_MLP_c =[0.0012,0.0002,-0.0007,-0.0008,0.0003,0.0008,-0.0036,-0.0024,-0.0017,-0.0070,-0.0025,-0.0003]
D2_LSTM_c = [0.0013,0.0024,0.0020,0.0008,0.0006,-0.0008,-0.0017,0.0010,0.0005,-0.0008,-0.0019,0.0001]
D2_XGB_c = [-0.0036,-0.0022,-0.0011,-0.0092,-0.0068,-0.0162,-0.0179,-0.0149,-0.0222,-0.0278,-0.0288,-0.0286]

D3_MLP_c = [-0.0009,-0.0006,-0.0005,-0.0012,-0.0011,0.0004,-0.0018,-0.0005,0.0004,-0.0030,-0.0003,-0.0007]
D3_XGB_c = [0.0001,-0.0002,-0.0001,-0.0047,-0.0056,-0.0074,-0.0054,-0.0054,-0.0139,-0.0121,-0.0079,-0.0044]

# %%
#plt.figure(figsize=(10, 6))
def percentage_formatter(x, pos):
    return f'{x * 100:.1f}%'

labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
plt.plot(labels, D1_MLP_c, label='Dataset 1 MLP (AUC)')
#plt.plot(labels, D1_MLP_MSE_c, label='Dataset 1 MLP (MSE)',linestyle='dashed')
plt.plot(labels, D1_XGB_c, label='Dataset 1 XGBoost (AUC)')
#plt.plot(labels, D1_XGB_MSE_c, label='Dataset 1 XGBoost (MSE)',linestyle='dashed')
plt.plot(labels, D1_LSTM_c, label='Dataset 1 LSTM (AUC)')
#plt.plot(labels, D1_LSTM_MSE_c, label='Dataset 1 LSTM (MSE)',linestyle='dashed')
plt.plot(labels, D2_MLP_c, label='Dataset 2 MLP (AUC)')
plt.plot(labels, D2_XGB_c, label='Dataset 2 XGBoost (AUC)')
plt.plot(labels, D2_LSTM_c, label='Dataset 2 LSTM (AUC)')
plt.plot(labels, D3_MLP_c, label='Dataset 3 MLP (AUC)')
plt.plot(labels, D3_XGB_c, label='Dataset 3 XGBoost (AUC)')

plt.gca().yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.xlabel('Data Distribution')
plt.ylabel('Performance Improvement')
#plt.title('Dateset 1 MLP')
plt.legend(fontsize=6,ncol=3)
plt.xticks(rotation='vertical')
#plt.ylim(-0.25, 0.5)
plt.show()

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.figure(figsize=(8, 7))

plt.plot(labels, non_dominant_d1_mlp, label='Non-dominant - Dataset 1 MLP', color='tab:blue')
plt.plot(labels, fl_d1_mlp, label='Federated - Dataset 1 MLP', color='tab:blue', linestyle='dashed')

plt.plot(labels, non_dominant_d2_mlp, label='Non-dominant - Dataset 2 MLP', color='tab:pink')
plt.plot(labels, fl_d2_mlp, label='Federated - Dataset 2 MLP', color='tab:pink', linestyle='dashed')

plt.plot(labels, non_dominant_d3_mlp, label='Non-dominant - Dataset 3 MLP', color='tab:red')
plt.plot(labels, fl_d3_mlp, label='Federated - Dataset 3 MLP', color='tab:red', linestyle='dashed')

plt.plot(labels, non_dominant_d1_lstm, label='Non-dominant - Dataset 1 LSTM',color='tab:orange')
plt.plot(labels, fl_d1_lstm, label='Federated - Dataset 1 LSTM', color='tab:orange', linestyle='dashed')

plt.plot(labels, non_dominant_d2_lstm, label='Non-dominant - Dataset 2 LSTM',color='tab:cyan')
plt.plot(labels, fl_d2_lstm, label='Federated - Dataset 2 LSTM', color='tab:cyan', linestyle='dashed')

plt.plot(labels, non_dominant_d1_xgb, label='Non-dominant - Dataset 1 XGBoost', color='tab:green')
plt.plot(labels, fl_d1_xgb, label='Federated - Dataset 1 XGBoost', color='tab:green', linestyle='dashed')

plt.plot(labels, non_dominant_d2_xgb, label='Non-dominant- Dataset 2 XGBoost', color='tab:purple')
plt.plot(labels, fl_d2_xgb, label='Federated - Dataset 2 XGBoost', color='tab:purple', linestyle='dashed')

plt.plot(labels, non_dominant_d3_xgb, label='Non-dominant - Dataset 3 XGBoost', color='tab:brown')
plt.plot(labels, fl_d3_xgb, label='Federated - Dataset 3 XGBoost', color='tab:brown', linestyle='dashed')

plt.xlabel('Data Distribution')
plt.ylabel('AUC')

plt.legend(fontsize=7, ncol=3, loc='upper left')
plt.xticks(rotation=90)
plt.ylim(0.45, 1.15)
plt.yticks(np.arange(0.45, 1, 0.1))

plt.tight_layout()
plt.show()

# %%
labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

plt.figure(figsize=(8, 7))

plt.plot(labels, dominant_d1_mlp, label='Dominant - Dataset 1 MLP', color='tab:blue')
plt.plot(labels, fl_d1_mlp, label='Federated - Dataset 1 MLP', color='tab:blue', linestyle='dashed')

plt.plot(labels, dominant_d2_mlp, label='Dominant - Dataset 2 MLP', color='tab:pink')
plt.plot(labels, fl_d2_mlp, label='Federated - Dataset 2 MLP', color='tab:pink', linestyle='dashed')

plt.plot(labels, dominant_d3_mlp, label='Dominant - Dataset 3 MLP', color='tab:red')
plt.plot(labels, fl_d3_mlp, label='Federated - Dataset 3 MLP', color='tab:red', linestyle='dashed')

plt.plot(labels, dominant_d1_lstm, label='Dominant - Dataset 1 LSTM',color='tab:orange')
plt.plot(labels, fl_d1_lstm, label='Federated - Dataset 1 LSTM', color='tab:orange', linestyle='dashed')

plt.plot(labels, dominant_d2_lstm, label='Dominant - Dataset 2 LSTM',color='tab:cyan')
plt.plot(labels, fl_d2_lstm, label='Federated - Dataset 2 LSTM', color='tab:cyan', linestyle='dashed')

plt.plot(labels, dominant_d1_xgb, label='Dominant - Dataset 1 XGBoost', color='tab:green')
plt.plot(labels, fl_d1_xgb, label='Federated - Dataset 1 XGBoost', color='tab:green', linestyle='dashed')

plt.plot(labels, dominant_d2_xgb, label='Dominant- Dataset 2 XGBoost', color='tab:purple')
plt.plot(labels, fl_d2_xgb, label='Federated - Dataset 2 XGBoost', color='tab:purple', linestyle='dashed')

plt.plot(labels, dominant_d3_xgb, label='Dominant - Dataset 3 XGBoost', color='tab:brown')
plt.plot(labels, fl_d3_xgb, label='Federated - Dataset 3 XGBoost', color='tab:brown', linestyle='dashed')

plt.xlabel('Data Distribution')
plt.ylabel('AUC')

plt.legend(fontsize=8, ncol=3, loc='upper left')
plt.xticks(labels, rotation=90)
plt.ylim(0.65, 1.1)
plt.yticks(np.arange(0.65, 1, 0.05))


plt.tight_layout()
plt.show()
