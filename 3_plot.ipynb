# %%
import matplotlib.pyplot as plt

# %%
MLP_50_50=[(1, 0.25696372985839844), (2, 0.2175365388393402), (3, 0.18803240358829498), (4, 0.16692674160003662), (5, 0.16508275270462036), (6, 0.16275936365127563), (7, 0.15826311707496643), (8, 0.15889957547187805), (9, 0.1585818976163864), (10, 0.15910056233406067), (11, 0.1567535102367401), (12, 0.1584070324897766), (13, 0.15833550691604614), (14, 0.15850940346717834), (15, 0.15732905268669128), (16, 0.15875300765037537), (17, 0.15590941905975342), (18, 0.15605592727661133), (19, 0.15696276724338531), (20, 0.15618161857128143), (21, 0.15905636548995972), (22, 0.1574641913175583), (23, 0.15434671938419342), (24, 0.1547364741563797), (25, 0.15609672665596008), (26, 0.15796834230422974), (27, 0.153464674949646), (28, 0.15157468616962433), (29, 0.1534539759159088), (30, 0.15249015390872955)]
MLP_60_40 = [(1, 0.23020093142986298), (2, 0.2097826451063156), (3, 0.18446379899978638), (4, 0.16906185448169708), (5, 0.16247044503688812), (6, 0.16115622222423553), (7, 0.16090771555900574), (8, 0.15916725993156433), (9, 0.1540849357843399), (10, 0.15354406833648682), (11, 0.15608319640159607), (12, 0.15983593463897705), (13, 0.1546599566936493), (14, 0.15447261929512024), (15, 0.1539773792028427), (16, 0.15554751455783844), (17, 0.1544819325208664), (18, 0.15586881339550018), (19, 0.15286920964717865), (20, 0.15345190465450287), (21, 0.15510699152946472), (22, 0.15209248661994934), (23, 0.15184147655963898), (24, 0.15157103538513184), (25, 0.1547592729330063), (26, 0.15431201457977295), (27, 0.15063786506652832), (28, 0.15074554085731506), (29, 0.15093988180160522), (30, 0.1539747416973114)]
MLP_80_20 =[(1, 0.2322271764278412), (2, 0.20108048617839813), (3, 0.1751890927553177), (4, 0.15939538180828094), (5, 0.1560927927494049), (6, 0.15553855895996094), (7, 0.15609849989414215), (8, 0.15707167983055115), (9, 0.15703584253787994), (10, 0.15635228157043457), (11, 0.151996910572052), (12, 0.1577184796333313), (13, 0.15171150863170624), (14, 0.1509125828742981), (15, 0.15385355055332184), (16, 0.15512649714946747), (17, 0.154957115650177), (18, 0.15225331485271454), (19, 0.1553984433412552), (20, 0.15398746728897095), (21, 0.15264040231704712), (22, 0.1533135026693344), (23, 0.15576104819774628), (24, 0.15550389885902405), (25, 0.14904753863811493), (26, 0.15310132503509521), (27, 0.15067802369594574), (28, 0.1500249058008194), (29, 0.15247687697410583), (30, 0.15011975169181824)]
MLP_34_33_33 =[(1, 0.2588854730129242), (2, 0.2384224683046341), (3, 0.22131051123142242), (4, 0.20510053634643555), (5, 0.1867547631263733), (6, 0.17268085479736328), (7, 0.1675434410572052), (8, 0.1594303846359253), (9, 0.16640695929527283), (10, 0.1612403690814972), (11, 0.15690937638282776), (12, 0.15295280516147614), (13, 0.1547263115644455), (14, 0.15328307449817657), (15, 0.1597450077533722), (16, 0.15594923496246338), (17, 0.15787489712238312), (18, 0.15765559673309326), (19, 0.16034583747386932), (20, 0.15215139091014862), (21, 0.15781041979789734), (22, 0.15326842665672302), (23, 0.1556898057460785), (24, 0.153313547372818), (25, 0.1541467010974884), (26, 0.15714582800865173), (27, 0.15353839099407196), (28, 0.15333425998687744), (29, 0.15783073008060455), (30, 0.15758877992630005)]
MLP_60_20_20 =[(1, 0.22972756624221802), (2, 0.21736463904380798), (3, 0.1894512176513672), (4, 0.17257700860500336), (5, 0.16185404360294342), (6, 0.1616530418395996), (7, 0.1617799699306488), (8, 0.15744265913963318), (9, 0.16115237772464752), (10, 0.15916600823402405), (11, 0.15671899914741516), (12, 0.15876513719558716), (13, 0.1522688865661621), (14, 0.15219153463840485), (15, 0.1548018902540207), (16, 0.15936413407325745), (17, 0.1522296518087387), (18, 0.15975983440876007), (19, 0.15077784657478333), (20, 0.1554877907037735), (21, 0.15580305457115173), (22, 0.1514086276292801), (23, 0.15479691326618195), (24, 0.15527936816215515), (25, 0.15731364488601685), (26, 0.15348026156425476), (27, 0.1556573510169983), (28, 0.1523573398590088), (29, 0.15473905205726624), (30, 0.1506582349538803)]
MLP_80_10_10 =[(1, 0.22937068343162537), (2, 0.19122201204299927), (3, 0.16792094707489014), (4, 0.15782392024993896), (5, 0.1586078703403473), (6, 0.15270578861236572), (7, 0.15479448437690735), (8, 0.1515873372554779), (9, 0.14987459778785706), (10, 0.15579670667648315), (11, 0.1537591516971588), (12, 0.1515982747077942), (13, 0.15848490595817566), (14, 0.16070306301116943), (15, 0.15628786385059357), (16, 0.15616920590400696), (17, 0.1561053842306137), (18, 0.1538374125957489), (19, 0.1573977768421173), (20, 0.15895946323871613), (21, 0.15492312610149384), (22, 0.15423624217510223), (23, 0.15715311467647552), (24, 0.15360049903392792), (25, 0.15567931532859802), (26, 0.15116584300994873), (27, 0.1579568088054657), (28, 0.15347011387348175), (29, 0.15941846370697021), (30, 0.15358026325702667)]
MLP_20_20_20_20_20 =[(1, 0.23610715568065643), (2, 0.23938621580600739), (3, 0.23435063660144806), (4, 0.22675293684005737), (5, 0.2157822549343109), (6, 0.20567916333675385), (7, 0.19309915602207184), (8, 0.18488037586212158), (9, 0.17953220009803772), (10, 0.17318302392959595), (11, 0.16954785585403442), (12, 0.1691139042377472), (13, 0.16016386449337006), (14, 0.1627955138683319), (15, 0.1598539501428604), (16, 0.16292668879032135), (17, 0.16295260190963745), (18, 0.15779587626457214), (19, 0.1556301712989807), (20, 0.15430064499378204), (21, 0.15792390704154968), (22, 0.15663598477840424), (23, 0.15691666305065155), (24, 0.15466119349002838), (25, 0.15625829994678497), (26, 0.15677234530448914), (27, 0.1560976356267929), (28, 0.15392620861530304), (29, 0.15505851805210114), (30, 0.15901128947734833)]
MLP_60_10_10_10_10 =[(1, 0.2376198023557663), (2, 0.23401542007923126), (3, 0.22991377115249634), (4, 0.22439375519752502), (5, 0.19765974581241608), (6, 0.17478539049625397), (7, 0.16519959270954132), (8, 0.16638022661209106), (9, 0.1701480746269226), (10, 0.16052773594856262), (11, 0.158692866563797), (12, 0.15615199506282806), (13, 0.15814515948295593), (14, 0.15874122083187103), (15, 0.15466447174549103), (16, 0.15985693037509918), (17, 0.15523909032344818), (18, 0.1531909555196762), (19, 0.15972329676151276), (20, 0.15589378774166107), (21, 0.15331345796585083), (22, 0.15735302865505219), (23, 0.1540968269109726), (24, 0.14838550984859467), (25, 0.15201100707054138), (26, 0.15629072487354279), (27, 0.15152877569198608), (28, 0.15735697746276855), (29, 0.1549636423587799), (30, 0.15353956818580627)]
MLP_80_5_5_5_5 =[(1, 0.22440436482429504), (2, 0.213456928730011), (3, 0.18206356465816498), (4, 0.18429973721504211), (5, 0.18271611630916595), (6, 0.18283545970916748), (7, 0.17752499878406525), (8, 0.1817624568939209), (9, 0.16586193442344666), (10, 0.16186222434043884), (11, 0.15976673364639282), (12, 0.15597034990787506), (13, 0.15509769320487976), (14, 0.15846426784992218), (15, 0.15833762288093567), (16, 0.15692438185214996), (17, 0.15419702231884003), (18, 0.16111810505390167), (19, 0.1562335342168808), (20, 0.16069044172763824), (21, 0.15420077741146088), (22, 0.15637534856796265), (23, 0.1502046436071396), (24, 0.15543627738952637), (25, 0.1527136266231537), (26, 0.14998316764831543), (27, 0.15798552334308624), (28, 0.1514599621295929), (29, 0.1520221084356308), (30, 0.15270750224590302)]
MLP_10_10_10_10_10_10_10_10_10_10 =[(1, 0.25283083319664), (2, 0.2535133957862854), (3, 0.25394898653030396), (4, 0.25337880849838257), (5, 0.2516672909259796), (6, 0.24831843376159668), (7, 0.2444283813238144), (8, 0.23920822143554688), (9, 0.23329900205135345), (10, 0.2277498096227646), (11, 0.22238850593566895), (12, 0.21630100905895233), (13, 0.20941436290740967), (14, 0.2051079124212265), (15, 0.19963374733924866), (16, 0.19395531713962555), (17, 0.19024166464805603), (18, 0.18459147214889526), (19, 0.1814517378807068), (20, 0.17778655886650085), (21, 0.17626971006393433), (22, 0.1725986748933792), (23, 0.16973111033439636), (24, 0.17027659714221954), (25, 0.16522088646888733), (26, 0.16657601296901703), (27, 0.1643616259098053), (28, 0.16335149109363556), (29, 0.1628877967596054), (30, 0.16398300230503082)]
MLP_60_10clients =[(1, 0.265170693397522), (2, 0.2644081115722656), (3, 0.2623937427997589), (4, 0.2597842216491699), (5, 0.25811341404914856), (6, 0.2562730610370636), (7, 0.21803508698940277), (8, 0.21398404240608215), (9, 0.1872166246175766), (10, 0.17134477198123932), (11, 0.1655968576669693), (12, 0.16567108035087585), (13, 0.15888701379299164), (14, 0.1639409363269806), (15, 0.1600913107395172), (16, 0.15779340267181396), (17, 0.15928326547145844), (18, 0.15971487760543823), (19, 0.16135862469673157), (20, 0.15543100237846375), (21, 0.15311220288276672), (22, 0.15635330975055695), (23, 0.15805166959762573), (24, 0.1596413403749466), (25, 0.16171088814735413), (26, 0.15769506990909576), (27, 0.15657919645309448), (28, 0.15471334755420685), (29, 0.15587234497070312), (30, 0.15863412618637085)]
MLP_80_10clients =[(1, 0.22483320534229279), (2, 0.19219356775283813), (3, 0.16778017580509186), (4, 0.16737869381904602), (5, 0.1641659289598465), (6, 0.1614505499601364), (7, 0.15898959338665009), (8, 0.1568654477596283), (9, 0.15794648230075836), (10, 0.1523032784461975), (11, 0.15239271521568298), (12, 0.15139484405517578), (13, 0.1596277952194214), (14, 0.15414217114448547), (15, 0.15313319861888885), (16, 0.15172013640403748), (17, 0.15503646433353424), (18, 0.15554293990135193), (19, 0.1572270542383194), (20, 0.15729308128356934), (21, 0.15393811464309692), (22, 0.15680156648159027), (23, 0.1517280638217926), (24, 0.14946094155311584), (25, 0.14624756574630737), (26, 0.14640794694423676), (27, 0.15209032595157623), (28, 0.14953333139419556), (29, 0.15027034282684326), (30, 0.16273850202560425)]

# %%
x_values1, y_values1 = zip(*MLP_50_50)
x_values2, y_values2 = zip(*MLP_60_40)
x_values3, y_values3 = zip(*MLP_80_20)

x_values4, y_values4 = zip(*MLP_34_33_33)
x_values5, y_values5 = zip(*MLP_60_20_20)
x_values6, y_values6 = zip(*MLP_80_10_10)

x_values7, y_values7 = zip(*MLP_20_20_20_20_20)
x_values8, y_values8 = zip(*MLP_60_10_10_10_10)
x_values9, y_values9 = zip(*MLP_80_5_5_5_5)

x_values10, y_values10 = zip(*MLP_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*MLP_60_10clients)
x_values12, y_values12 = zip(*MLP_80_10clients)

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(0.14,0.27)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(0.14,0.27)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(0.14,0.27)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0.14,0.27)
plt.show()

# %% [markdown]
# MLP Summary

# %%
classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

central = 0.8346
classes_2 = ["50-50", "60-40", "80-20"]
dominant_2 = [0.8327, 0.8330, 0.8342]
non_dominant_2 = [0.8327, 0.8317, 0.8289]
fl_2 = [0.8339, 0.8342, 0.8342]


classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
dominant_3 = [0.8311, 0.8325, 0.8337]
non_dominant_3 = [0.8311,0.8280,0.8231,]
fl_3 = [0.8337, 0.8337, 0.8350]

classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
dominant_5 = [0.8285, 0.8319, 0.8334]
non_dominant_5 = [0.8285,0.817563917,0.810475185,]
fl_5 = [0.8331, 0.8343, 0.8350]

classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
dominant_10 = [0.8214, 0.8325, 0.8307]
non_dominant_10 = [0.8214,0.80570552,0.80327009,]
fl_10 = [0.8322, 0.8343, 0.8340]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))
plt.plot(classes, local_dominant, label='Local Dominant', color= 'tab:cyan')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant',color= 'tab:orange')
plt.plot(classes, auc_fl, label='Federated',color= 'tab:green')
plt.plot(classes, auc_central, label='Centralised',color= 'tab:red')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 3 MLP')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# %%
# import numpy as np
#
# plt.figure(figsize=(40, 20))
# fig, ax = plt.subplots(2, 2,figsize=(12, 8))
# plt.tight_layout(w_pad=4, h_pad=4)
#
#
# ax1 = ax[0, 0]
# ax2 = ax[0, 1]
# ax3 = ax[1, 0]
# ax4 = ax[1, 1]
#
#
# xticks = np.arange(len(classes_2))
#
# ax1.bar(xticks, dominant_2, width=0.25, color='tab:orange',label="Local Dominant")
# ax1.bar(xticks + 0.25, non_dominant_2,width=0.25, color='tab:green',label="Local Non-dominant")
# ax1.bar(xticks + 0.5, fl_2,width=0.25, color='tab:cyan',label="Federated Learning")
# ax1.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax1.set_title("(a) 2 Clients")
# ax1.set_xlabel("Data Distribution")
# ax1.set_ylabel("AUC")
# ax1.legend(loc='upper left', fontsize=7)
# ax1.set_ylim(0.78, 0.85)
# ax1.set_xticks(xticks + 0.25)
# ax1.set_xticklabels(classes_2)
#
# ax2.bar(xticks, dominant_3, width=0.25, color='tab:orange',label="Local Dominant")
# ax2.bar(xticks + 0.25, non_dominant_3,width=0.25, color='tab:green',label="Local Non-dominant")
# ax2.bar(xticks + 0.5, fl_3,width=0.25, color='tab:cyan',label="Federated Learning")
# ax2.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax2.set_title("(b) 3 Clients")
# ax2.set_xlabel('Data Distribution')
# ax2.set_ylabel('AUC')
# ax2.legend(loc='upper left', fontsize=7)
# ax2.set_ylim(0.78, 0.85)
# ax2.set_xticks(xticks + 0.25)
# ax2.set_xticklabels(classes_3)
#
# ax3.bar(xticks, dominant_5, width=0.25, color='tab:orange',label="Local Dominant")
# ax3.bar(xticks + 0.25, non_dominant_5,width=0.25, color='tab:green',label="Local Non-dominant")
# ax3.bar(xticks + 0.5, fl_5,width=0.25, color='tab:cyan',label="Federated Learning")
# ax3.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax3.set_title("(c) 5 Clients")
# ax3.set_xlabel('Data Distribution')
# ax3.set_ylabel('AUC')
# ax3.legend(loc='upper left', fontsize=7)
# ax3.set_ylim(0.78, 0.85)
# ax3.set_xticks(xticks + 0.25)
# ax3.set_xticklabels(classes_5)
#
# ax4.bar(xticks, dominant_10, width=0.25, color='tab:orange',label="Local Dominant")
# ax4.bar(xticks + 0.25, non_dominant_10,width=0.25, color='tab:green',label="Local Non-dominant")
# ax4.bar(xticks + 0.5, fl_10,width=0.25, color='tab:cyan',label="Federated Learning")
# ax4.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax4.set_title("(d) 10 Clients")
# ax4.set_xlabel('Data Distribution')
# ax4.set_ylabel('AUC')
# ax4.legend(loc='upper left', fontsize=7)
# ax4.set_ylim(0.78, 0.85)
# ax4.set_xticks(xticks + 0.25)
# ax4.set_xticklabels(classes_10)
# plt.show()

# %%
XGB_50_50=[(0, 0.24817562), (1, 0.1819968), (2, 0.13471934), (3, 0.10041631), (4, 0.07637986), (5, 0.06176197), (6, 0.054505903), (7, 0.05193226), (8, 0.051512867), (9, 0.051406555), (10, 0.05130906), (11, 0.051015586), (12, 0.050681986), (13, 0.05055481), (14, 0.050536297), (15, 0.050001606), (16, 0.0500316), (17, 0.049915545), (18, 0.049971208), (19, 0.04997557), (20, 0.04974362)]
XGB_60_40 =[(0, 0.24046394), (1, 0.1908257), (2, 0.14545764), (3, 0.10743729), (4, 0.07897157), (5, 0.062373772), (6, 0.054503076), (7, 0.052073486), (8, 0.05164488), (9, 0.051225748), (10, 0.05115165)]
[0.6, 0.2, 0.2]

XGB_80_20 =[(0, 0.22916526), (1, 0.16734834), (2, 0.12520741), (3, 0.09361309), (4, 0.07159837), (5, 0.059149347), (6, 0.053660814), (7, 0.052319996), (8, 0.051879425), (9, 0.05162071), (10, 0.051756226), (11, 0.05128925), (12, 0.05112849), (13, 0.051076327), (14, 0.051114667), (15, 0.05069439), (16, 0.05060782), (17, 0.05037962), (18, 0.050447814), (19, 0.05033099), (20, 0.05060996)]
XGB_34_33_33 =[(0, 0.23493896), (1, 0.17962377), (2, 0.13599643), (3, 0.10063647), (4, 0.0751986), (5, 0.060090844), (6, 0.05347), (7, 0.051637452), (8, 0.051715244), (9, 0.051337853), (10, 0.050953977), (11, 0.05098461), (12, 0.050819326), (13, 0.05147589), (14, 0.05069664), (15, 0.050240852), (16, 0.050272427), (17, 0.049920708), (18, 0.05071095), (19, 0.04982586), (20, 0.050254762)]
XGB_60_20_20 =[(0, 0.22328693), (1, 0.16690068), (2, 0.12675773), (3, 0.09689903), (4, 0.07467059), (5, 0.060320858), (6, 0.054523684), (7, 0.052288257), (8, 0.051960465), (9, 0.05176122), (10, 0.05143641), (11, 0.051571667), (12, 0.050991606), (13, 0.05066227), (14, 0.05073137), (15, 0.050607577), (16, 0.05056317), (17, 0.050183147), (18, 0.050131544), (19, 0.050010584), (20, 0.050201274)]
XGB_80_10_10 =[(0, 0.24386197), (1, 0.18235922), (2, 0.12871544), (3, 0.08814612), (4, 0.063491106), (5, 0.054221094), (6, 0.05220344), (7, 0.05170432), (8, 0.0511967), (9, 0.050993785), (10, 0.05084899), (11, 0.05089658), (12, 0.05014523), (13, 0.05054567), (14, 0.050894815), (15, 0.049806397), (16, 0.050576758), (17, 0.050782822), (18, 0.050773013), (19, 0.050880596), (20, 0.05118059)]

XGB_20_20_20_20_20 =[(0, 0.26334506), (1, 0.21459764), (2, 0.16254161), (3, 0.113157965), (4, 0.076749116), (5, 0.057487715), (6, 0.051884104), (7, 0.051788244), (8, 0.05117276), (9, 0.050702672), (10, 0.050736703), (11, 0.050489377), (12, 0.05058744), (13, 0.050374743), (14, 0.050422158), (15, 0.05054563), (16, 0.050205063), (17, 0.050278097), (18, 0.050814606), (19, 0.04991424), (20, 0.050217263)]
XGB_60_10_10_10_10 =[(0, 0.22810547), (1, 0.17242861), (2, 0.11842692), (3, 0.07980319), (4, 0.058599934), (5, 0.05278971), (6, 0.053334847), (7, 0.052155703), (8, 0.051809505), (9, 0.051690895), (10, 0.051737066), (11, 0.051195018), (12, 0.05148812), (13, 0.050936062), (14, 0.050994176), (15, 0.051278427), (16, 0.050409272), (17, 0.050739106), (18, 0.05057313), (19, 0.050520163), (20, 0.050788403)]
XGB_80_5_5_5_5 =[(0, 0.22823942), (1, 0.17200309), (2, 0.11077884), (3, 0.07301981), (4, 0.056282), (5, 0.05332656), (6, 0.05310323), (7, 0.052583892), (8, 0.05143448), (9, 0.05218902), (10, 0.052456), (11, 0.052990697), (12, 0.051110044), (13, 0.0523222), (14, 0.052235816), (15, 0.051070653), (16, 0.052313328), (17, 0.052400194), (18, 0.052342147), (19, 0.054413866), (20, 0.050889067)]

XGB_10_10_10_10_10_10_10_10_10_10 =[(0, 0.24516228), (1, 0.16396207), (2, 0.091928296), (3, 0.05842937), (4, 0.05275563), (5, 0.05230871), (6, 0.052557), (7, 0.05145835), (8, 0.052416407), (9, 0.05090902), (10, 0.05106741), (11, 0.05055122), (12, 0.050932366), (13, 0.05054811), (14, 0.050609745), (15, 0.05052751), (16, 0.050967738), (17, 0.05063299), (18, 0.05125332), (19, 0.050212122), (20, 0.050535355)]
XGB_60_10clients =[(0, 0.24590686), (1, 0.15924262), (2, 0.091171585), (3, 0.057507984), (4, 0.052750356), (5, 0.052145496), (6, 0.05219193), (7, 0.051683325), (8, 0.05189841), (9, 0.05199794), (10, 0.051752023), (11, 0.051482633), (12, 0.051171836), (13, 0.051210348), (14, 0.05177536), (15, 0.051685855), (16, 0.05127251), (17, 0.050903156), (18, 0.051757876), (19, 0.050904248), (20, 0.051040392)]
XGB_80_10clients =[(0, 0.22171843), (1, 0.15321699), (2, 0.08902228), (3, 0.059161145), (4, 0.053995516), (5, 0.05542136), (6, 0.054033875), (7, 0.052959252), (8, 0.05230207), (9, 0.05335706), (10, 0.052797854), (11, 0.053144783), (12, 0.05238154), (13, 0.05310229), (14, 0.05222114), (15, 0.050524943), (16, 0.052041993), (17, 0.05063753), (18, 0.051823933), (19, 0.04972549), (20, 0.05192524)]

# %%
x_values1, y_values1 = zip(*XGB_50_50)
x_values2, y_values2 = zip(*XGB_60_40)
x_values3, y_values3 = zip(*XGB_80_20)

x_values4, y_values4 = zip(*XGB_34_33_33)
x_values5, y_values5 = zip(*XGB_60_20_20)
x_values6, y_values6 = zip(*XGB_80_10_10)

x_values7, y_values7 = zip(*XGB_20_20_20_20_20)
x_values8, y_values8 = zip(*XGB_60_10_10_10_10)
x_values9, y_values9 = zip(*XGB_80_5_5_5_5)

x_values10, y_values10 = zip(*XGB_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*XGB_60_10clients)
x_values12, y_values12 = zip(*XGB_80_10clients)

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(0.045,0.08)
ax1.set_xticks(np.arange(0, 21, 2))

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(0.045,0.08)
ax2.set_xticks(np.arange(0, 21, 2))

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(0.045,0.08)
ax3.set_xticks(np.arange(0, 21, 2))

ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0.045,0.08)
ax4.set_xticks(np.arange(0, 21, 2))

plt.show()

# %%
import numpy as np
# XGB
central = 0.8652

classes_2 = ["50-50", "60-40", "80-20"]
dominant_2 = [0.8622, 0.8632, 0.8641]
non_dominant_2 = [0.8622, 0.8606, 0.8553]
fl_2 = [0.8653, 0.8650, 0.8651]


classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
dominant_3 = [0.8579, 0.8632, 0.8641]
non_dominant_3 = [0.8579,0.8544,0.8464,]
fl_3 = [0.8611, 0.8604, 0.8589]

classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
dominant_5 = [0.8552, 0.8632, 0.8641]
non_dominant_5 = [0.8552,0.8458,0.8288,]
fl_5 = [0.8606, 0.8606, 0.8532]

classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
dominant_10 = [0.8463, 0.8632, 0.8641]
non_dominant_10 = [0.8463,0.8282,0.8158,]
fl_10 = [0.8548, 0.8584, 0.8614]


classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))
plt.plot(classes, local_dominant, label='Local Dominant', color= 'tab:cyan')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant',color= 'tab:orange')
plt.plot(classes, auc_fl, label='Federated',color= 'tab:green')
plt.plot(classes, auc_central, label='Centralised',color= 'tab:red')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 3 XGB')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# plt.figure(figsize=(40, 20))
# fig, ax = plt.subplots(2, 2,figsize=(12, 8))
# plt.tight_layout(w_pad=4, h_pad=4)
#
# ax1 = ax[0, 0]
# ax2 = ax[0, 1]
# ax3 = ax[1, 0]
# ax4 = ax[1, 1]
#
#
# xticks = np.arange(len(classes_2))
#
# ax1.bar(xticks, dominant_2, width=0.25, color='tab:orange',label="Local Dominant")
# ax1.bar(xticks + 0.25, non_dominant_2,width=0.25, color='tab:green',label="Local Non-dominant")
# ax1.bar(xticks + 0.5, fl_2,width=0.25, color='tab:cyan',label="Federated Learning")
# ax1.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax1.set_title("(a) 2 Clients")
# ax1.set_xlabel("Data Distribution")
# ax1.set_ylabel("AUC")
# ax1.legend(loc='upper left', fontsize=7)
# ax1.set_ylim(0.8, 0.89)
# ax1.set_xticks(xticks + 0.25)
# ax1.set_xticklabels(classes_2)
#
# ax2.bar(xticks, dominant_3, width=0.25, color='tab:orange',label="Local Dominant")
# ax2.bar(xticks + 0.25, non_dominant_3,width=0.25, color='tab:green',label="Local Non-dominant")
# ax2.bar(xticks + 0.5, fl_3,width=0.25, color='tab:cyan',label="Federated Learning")
# ax2.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax2.set_title("(b) 3 Clients")
# ax2.set_xlabel('Data Distribution')
# ax2.set_ylabel('AUC')
# ax2.legend(loc='upper left', fontsize=7)
# ax2.set_ylim(0.8, 0.89)
# ax2.set_xticks(xticks + 0.25)
# ax2.set_xticklabels(classes_3)
#
# ax3.bar(xticks, dominant_5, width=0.25, color='tab:orange',label="Local Dominant")
# ax3.bar(xticks + 0.25, non_dominant_5,width=0.25, color='tab:green',label="Local Non-dominant")
# ax3.bar(xticks + 0.5, fl_5,width=0.25, color='tab:cyan',label="Federated Learning")
# ax3.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax3.set_title("(c) 5 Clients")
# ax3.set_xlabel('Data Distribution')
# ax3.set_ylabel('AUC')
# ax3.legend(loc='upper left', fontsize=7)
# ax3.set_ylim(0.8, 0.89)
# ax3.set_xticks(xticks + 0.25)
# ax3.set_xticklabels(classes_5)
#
# ax4.bar(xticks, dominant_10, width=0.25, color='tab:orange',label="Local Dominant")
# ax4.bar(xticks + 0.25, non_dominant_10,width=0.25, color='tab:green',label="Local Non-dominant")
# ax4.bar(xticks + 0.5, fl_10,width=0.25, color='tab:cyan',label="Federated Learning")
# ax4.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax4.set_title("(d) 10 Clients")
# ax4.set_xlabel('Data Distribution')
# ax4.set_ylabel('AUC')
# ax4.legend(loc='upper left', fontsize=7)
# ax4.set_ylim(0.8, 0.89)
# ax4.set_xticks(xticks + 0.25)
# ax4.set_xticklabels(classes_10)
# plt.show()
