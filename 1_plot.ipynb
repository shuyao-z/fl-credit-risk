x_values2, y_values2 = zip(*MLP_60_40)
x_values3, y_values3 = zip(*MLP_80_20)

x_values4, y_values4 = zip(*MLP_34_33_33)
x_values5, y_values5 = zip(*MLP_60_20_20)
x_values6, y_values6 = zip(*MLP_80_10_10)

x_values7, y_values7 = zip(*MLP_20_20_20_20_20)
x_values8, y_values8 = zip(*MLP_60_10_10_10_10)
x_values9, y_values9 = zip(*MLP_80_5_5_5_5)

x_values10, y_values10 = zip(*MLP_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*MLP_60_10clients)
x_values12, y_values12 = zip(*MLP_80_10clients)

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(1,5)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(1,5)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(1,5)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(1,5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.figure(figsize=(40, 20))
#       2 fig, ax = plt.subplots(2, 2,figsize=(12, 8))
#       3 plt.tight_layout(w_pad=4, h_pad=4)
#
# NameError: name 'plt' is not defined

# %%
# %%
x_values1, y_values1 = zip(*LSTM_50_50)
x_values2, y_values2 = zip(*LSTM_60_40)
x_values3, y_values3 = zip(*LSTM_80_20)

x_values4, y_values4 = zip(*LSTM_34_33_33)
x_values5, y_values5 = zip(*LSTM_60_20_20)
x_values6, y_values6 = zip(*LSTM_80_10_10)

x_values7, y_values7 = zip(*LSTM_20_20_20_20_20)
x_values8, y_values8 = zip(*LSTM_60_10_10_10_10)
x_values9, y_values9 = zip(*LSTM_80_5_5_5_5)

x_values10, y_values10 = zip(*LSTM_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*LSTM_60_10clients)
x_values12, y_values12 = zip(*LSTM_80_10clients)

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(0,3)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(0,3)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(0,3)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0,3)
plt.show()

# %%
# 0.5 sampling rate
XGB_60_10_10_10_10 =[(0, 123.83918669131238), (1, 3.722735674676525), (2, 4.038817005545287), (3, 6.805914972273568), (4, 2.3696857670979665), (5, 3.8280961182994453), (6, 5.7818853974122), (7, 5.22365988909427), (8, 3.4953789279112755), (9, 3.879852125693161), (10, 5.839186691312385), (11, 4.151571164510166), (12, 3.2495378927911274), (13, 2.232902033271719), (14, 4.3345656192236595), (15, 5.053604436229205)]
XGB_80_5_5_5_5 = [(0, 118.63955637707949), (1, 3.622920517560074), (2, 6.7467652495378925), (3, 6.728280961182994), (4, 6.964879852125693), (5, 5.972273567467653), (6, 5.094269870609981), (7, 3.789279112754159), (8, 6.406654343807763), (9, 5.935304990757856), (10, 6.598890942698706), (11, 5.617375231053605), (12, 4.696857670979667), (13, 6.121996303142329), (14, 7.423290203327172), (15, 2.6173752310536043)]
XGB_10_10_10_10_10_10_10_10_10_10=[(0, 43.35304990757856), (1, 4.700554528650647), (2, 4.242144177449168), (3, 6.565619223659889), (4, 3.7837338262476896), (5, 3.846580406654344), (6, 5.146025878003697), (7, 4.6802218114602585), (8, 4.480591497227357), (9, 4.654343807763401), (10, 4.404805914972274), (11, 4.090573012939002), (12, 3.733826247689464), (13, 5.0831792975970425), (14, 4.7818853974122), (15, 3.8613678373382623)]
XGB_60_10clients=[(0, 124.14417744916821), (1, 6.728280961182994), (2, 7.121996303142329), (3, 7.116451016635859), (4, 7.54898336414048), (5, 6.303142329020333), (6, 5.939001848428836), (7, 5.9833641404805915), (8, 4.876155268022181), (9, 7.438077634011091), (10, 5.136783733826248), (11, 4.844731977818854), (12, 5.536044362292052), (13, 5.759704251386322), (14, 5.791127541589649), (15, 4.715341959334566)]
XGB_80_10clients=[(0, 84.62846580406655), (1, 7.199630314232902), (2, 6.9075785582255085), (3, 12.804066543438077), (4, 8.380776340110906), (5, 3.6266173752310538), (6, 6.024029574861368), (7, 3.5415896487985212), (8, 8.99815157116451), (9, 10.580406654343808), (10, 6.247689463955638), (11, 9.423290203327172), (12, 7.205175600739372), (13, 8.88539741219963), (14, 5.489833641404806), (15, 8.402957486136783)]

# %%
x_values1, y_values1 = zip(*XGB_50_50)
x_values2, y_values2 = zip(*XGB_60_40)
x_values3, y_values3 = zip(*XGB_80_20)

x_values4, y_values4 = zip(*XGB_34_33_33)
x_values5, y_values5 = zip(*XGB_60_20_20)
x_values6, y_values6 = zip(*XGB_80_10_10)

x_values7, y_values7 = zip(*XGB_20_20_20_20_20)
x_values8, y_values8 = zip(*XGB_60_10_10_10_10)
x_values9, y_values9 = zip(*XGB_80_5_5_5_5)

x_values10, y_values10 = zip(*XGB_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*XGB_60_10clients)
x_values12, y_values12 = zip(*XGB_80_10clients)

x_values1_1, y_values1_1 = zip(*XGB_50_50)
x_values2_1, y_values2_1 = zip(*XGB_60_40)
x_values3_1, y_values3_1 = zip(*XGB_80_20)

x_values4_1, y_values4_1 = zip(*XGB_34_33_33)
x_values5_1, y_values5_1 = zip(*XGB_60_20_20)
x_values6_1, y_values6_1 = zip(*XGB_80_10_10)

x_values7_1, y_values7_1 = zip(*XGB_20_20_20_20_20)
x_values8_1, y_values8_1 = zip(*XGB_60_10_10_10_10)
x_values9_1, y_values9_1 = zip(*XGB_80_5_5_5_5)

x_values10_1, y_values10_1 = zip(*XGB_10_10_10_10_10_10_10_10_10_10)
x_values11_1, y_values11_1 = zip(*XGB_60_10clients)
x_values12_1, y_values12_1 = zip(*XGB_80_10clients)

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(1,15)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(1,15)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(1,15)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0,15)
plt.show()

# %%
#sampling rate 1
XGB_80_5_5_5_5 = [(0, 106.88354898336414), (1, 3.641404805914972), (2, 3.0646950092421443), (3, 2.500924214417745), (4, 2.3031423290203326), (5, 2.201478743068392), (6, 2.234750462107209), (7, 2.1182994454713495), (8, 2.123844731977819), (9, 2.0295748613678373), (10, 1.988909426987061), (11, 1.9574861367837337), (12, 1.9260628465804066), (13, 1.8983364140480592), (14, 1.8983364140480592), (15, 1.9593345656192236)]
XGB_60_10_10_10_10 = [(0, 124.14417744916821), (1, 3.192236598890943), (2, 2.5064695009242146), (3, 2.299445471349353), (4, 2.2717190388170057), (5, 2.2181146025878005), (6, 2.290203327171904), (7, 2.467652495378928), (8, 2.22365988909427), (9, 2.3401109057301293), (10, 2.2809611829944547), (11, 2.22365988909427), (12, 2.190388170055453), (13, 2.1312384473197783), (14, 2.190388170055453), (15, 2.3271719038817005)]
XGB_34_33_33 = [(0, 105.21256931608133), (1, 2.3419593345656193), (2, 1.8687615526802217), (3, 1.8022181146025877), (4, 1.8964879852125693), (5, 1.7282809611829943), (6, 1.902033271719039), (7, 1.9260628465804066), (8, 1.8817005545286507), (9, 1.7689463955637708), (10, 1.866913123844732), (11, 1.8687615526802217), (12, 1.975970425138632), (13, 1.9741219963031422), (14, 1.9537892791127542), (15, 1.9611829944547134)]
XGB_60_10clients = [(0, 124.14417744916821), (1, 3.988909426987061), (2, 2.898336414048059), (3, 2.55637707948244), (4, 2.4528650646950094), (5, 2.412199630314233), (6, 2.3659889094269873), (7, 2.2513863216266174), (8, 2.2273567467652495), (9, 2.2717190388170057), (10, 2.188539741219963), (11, 2.195933456561922), (12, 2.201478743068392), (13, 2.147874306839187), (14, 2.133086876155268), (15, 2.1256931608133085)]
XGB_80_10clients = [(0, 85.452865064695), (1, 7.648798521256932), (2, 3.924214417744917), (3, 3.210720887245841), (4, 2.7855822550831792), (5, 2.6192236598890943), (6, 2.4731977818853976), (7, 2.301293900184843), (8, 2.199630314232902), (9, 2.1182994454713495), (10, 2.1386321626617377), (11, 2.21996303142329), (12, 2.192236598890943), (13, 2.144177449168207), (14, 2.144177449168207), (15, 2.1275415896487986)]

# %%
x_values1, y_values1 = zip(*XGB_50_50)
x_values2, y_values2 = zip(*XGB_60_40)
x_values3, y_values3 = zip(*XGB_80_20)

x_values4, y_values4 = zip(*XGB_34_33_33)
x_values5, y_values5 = zip(*XGB_60_20_20)
x_values6, y_values6 = zip(*XGB_80_10_10)

x_values7, y_values7 = zip(*XGB_20_20_20_20_20)
x_values8, y_values8 = zip(*XGB_60_10_10_10_10)
x_values9, y_values9 = zip(*XGB_80_5_5_5_5)
#
x_values10, y_values10 = zip(*XGB_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*XGB_60_10clients)
x_values12, y_values12 = zip(*XGB_80_10clients)

# %%
#XGB sampling rate 0.5 and 1
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)

ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

dark_gray = (0.4, 0.4, 0.4)

line_style_legend = ax1.legend(handles=[mlines.Line2D([], [], marker='.', linestyle='-', color=dark_gray, label='sampling rate = 1'),mlines.Line2D([], [], linestyle='dashed', color=dark_gray, label='sampling rate = 0.5')], bbox_to_anchor=[0.81, 1],fontsize=8)
ax1.add_artist(line_style_legend)

line_style_legend = ax2.legend(handles=[
mlines.Line2D([], [], linestyle='-', marker='.',color=dark_gray, label='sampling rate = 1'),
mlines.Line2D([], [], linestyle='dashed', color=dark_gray, label='sampling rate = 0.5')
], bbox_to_anchor=[0.78, 1],fontsize=8)
ax2.add_artist(line_style_legend)

line_style_legend = ax3.legend(handles=[
mlines.Line2D([], [], linestyle='-', marker='.',color=dark_gray, label='sampling rate = 1'),
mlines.Line2D([], [], linestyle='dashed', color=dark_gray, label='sampling rate = 0.5')
], bbox_to_anchor=[0.7, 1],fontsize=8)
ax3.add_artist(line_style_legend)

line_style_legend = ax4.legend(handles=[
mlines.Line2D([], [], linestyle='-', marker='.',color=dark_gray, label='sampling rate = 1'),
mlines.Line2D([], [], linestyle='dashed', color=dark_gray, label='sampling rate = 0.5')
], bbox_to_anchor=[0.65, 1],fontsize=8)
ax4.add_artist(line_style_legend)

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.plot(x_values1_1, y_values1_1, linestyle='dashed',color='tab:orange', label='50-50')
ax1.plot(x_values2_1, y_values2_1,  linestyle='dashed',color='tab:green', label='60-40')
ax1.plot(x_values3_1, y_values3_1, linestyle='dashed',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
#ax1.legend()
color_legend = ax1.legend(handles=[
        mpatches.Patch(color='tab:orange', label='50-50'),
        mpatches.Patch(color='tab:green', label='60-40'),
        mpatches.Patch(color='tab:cyan', label='80-20')
    ], loc='upper right',fontsize=8)
ax1.set_ylim(1,15)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.plot(x_values4_1, y_values4_1, linestyle='dashed',color='tab:orange', label='34-33-33')
ax2.plot(x_values5_1, y_values5_1, linestyle='dashed', color='tab:green', label='60-20-20')
ax2.plot(x_values6_1, y_values6_1, linestyle='dashed', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
#ax2.legend()
color_legend = ax2.legend(handles=[
        mpatches.Patch(color='tab:orange', label='34-33-33'),
        mpatches.Patch(color='tab:green', label='60-20-20'),
        mpatches.Patch(color='tab:cyan', label='80-10-10')
    ], loc='upper right',fontsize=8)
ax2.set_ylim(1,15)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.plot(x_values7_1, y_values7_1, linestyle='dashed', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8_1, y_values8_1, linestyle='dashed', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9_1, y_values9_1,  linestyle='dashed', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
#ax3.legend()
color_legend = ax3.legend(handles=[
        mpatches.Patch(color='tab:orange', label='20-20-20-20-20'),
        mpatches.Patch(color='tab:green', label='60-10-10-10-10'),
        mpatches.Patch(color='tab:cyan', label='80-5-5-5-5')
    ], loc='upper right',fontsize=8)
ax3.set_ylim(1,15)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-\n10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.plot(x_values10_1, y_values10_1, linestyle='dashed', color='tab:orange',label='10-10-10-10-10-\n10-10-10-10-10')
ax4.plot(x_values11_1, y_values11_1,  linestyle='dashed', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12_1, y_values12_1,  linestyle='dashed', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
#ax4.legend(fontsize=8)
color_legend = ax4.legend(handles=[
        mpatches.Patch(color='tab:orange', label='10-10-10-10-10-\n10-10-10-10-10'),
        mpatches.Patch(color='tab:green', label='60-5-5-5-5-4-4-4-4-4'),
        mpatches.Patch(color='tab:cyan', label='80-3-3-2-2-2-2-2-2-2')
    ], loc='upper right',fontsize=8)
ax4.set_ylim(1,15)


plt.show()

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(1,15)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(1,15)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(1,15)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0,15)
plt.show()

# %%
classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

central = 0.9066
dominant_2 = [0.8770, 0.8856, 0.8979]
non_dominant_2 = [0.8770, 0.8804,0.8471,]
fl_2 = [0.8884, 0.8924,0.8844,]

dominant_3 = [0.8673, 0.8789, 0.8986]
non_dominant_3 = [0.8673, 0.8637,0.8421,]
fl_3 = [0.8866, 0.8897,0.8831,]

dominant_5 = [0.8544, 0.8777, 0.8944]
non_dominant_5 = [0.8544, 0.8383,0.8216,]
fl_5 = [0.8814, 0.8812,0.8887,]

dominant_10 = [0.8270, 0.8858, 0.8926]
non_dominant_10 = [0.8270, 0.8139,0.8015,]
fl_10 = [0.8753, 0.8794,0.8809,]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))


plt.plot(classes, local_dominant, label='Local Dominant')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant')
plt.plot(classes, auc_fl, label='Federated')
plt.plot(classes, auc_central, label='Centralised')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 1 MLP')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# %%
classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]


central = 0.9714
classes_2 = ["50-50", "60-40", "80-20"]
dominant_2 = [0.9713, 0.9664, 0.9756]
non_dominant_2 = [0.9713, 0.9634,0.9625,]
fl_2 = [0.9769, 0.9790, 0.9801]

classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
dominant_3 = [0.9600, 0.9656, 0.9735]
non_dominant_3 = [0.9600, 0.9566,0.9483,]
fl_3 = [0.9769, 0.9737,0.9759,]

classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
dominant_5 = [0.9510, 0.9631, 0.9747]
non_dominant_5 = [0.9510, 0.9389,0.9192,]
fl_5 = [0.9758, 0.9767,0.9769,]

classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
dominant_10 = [0.9393, 0.9680, 0.9710]
non_dominant_10 = [0.9393, 0.9173,0.7329,]
fl_10 = [0.9770, 0.9760,0.9790,]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))
plt.plot(classes, local_dominant, label='Local Dominant', color= 'tab:cyan')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant',color= 'tab:orange')
plt.plot(classes, auc_fl, label='Federated',color= 'tab:green')
plt.plot(classes, auc_central, label='Centralised',color= 'tab:red')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 1 LSTM')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# %%
#XGB
central = 0.9154
classes_2 = ["50-50", "60-40", "80-20"]
dominant_2 = [0.8902, 0.8999, 0.9092]
non_dominant_2 = [0.8902, 0.8757, 0.8480, ]
fl_2 = [0.9086, 0.9168, 0.9102]

classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
dominant_3 = [0.8702, 0.8912, 0.9080]
non_dominant_3 = [0.8702, 0.8515, 0.8266, ]
fl_3 = [0.9068, 0.9095, 0.9084, ]

classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
dominant_5 = [0.8501, 0.8962, 0.9076]
non_dominant_5 = [0.8501, 0.8270, 0.7812, ]
fl_5 = [0.9079, 0.9018, 0.8909, ]

classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
dominant_10 = [0.8249, 0.9025, 0.9109]
non_dominant_10 = [0.8249, 0.7850, 0.7342, ]
fl_10 = [0.8799, 0.8813, 0.8896, ]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))
plt.plot(classes, local_dominant, label='Local Dominant', color= 'tab:cyan')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant',color= 'tab:orange')
plt.plot(classes, auc_fl, label='Federated',color= 'tab:green')
plt.plot(classes, auc_central, label='Centralised',color= 'tab:red')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 1 XGB')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np

# Data

def plot(D1_MLP):
    # Labels for the x-axis
    labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

    # Create a bar chart with gaps
    fig, ax = plt.subplots()
    bar_width = 0.6  # Width of each bar
    gap_width = 0.2  # Width of the gap between groups of bars

    # Calculate the x-positions for each group of bars
    x_positions = np.arange(len(labels))
    group_colors =  ['tab:red', 'tab:cyan','tab:orange','tab:green']
    # Plot the bars for each group
    for i in range(0, len(D1_MLP), 3):
        if i == 0:
            label = '2 Clients'
            colour = 'tab:red'
        if i == 3:
            label = '3 Clients'
            colour = 'tab:cyan'
        if i == 6:
            label = '5 Clients'
            colour = 'tab:orange'
        if i ==9:
            label = '10 Clients'
            colour = 'tab:green'
        ax.bar(x_positions[i:i + 3], D1_MLP[i:i + 3], width=bar_width, label=label, color=colour)

    # Set the x-axis labels
    ax.set_xticks(x_positions)
    ax.set_xticklabels(labels)

    # Add labels and title
    plt.xlabel('Data Distribution')
    plt.ylabel('Performance Improvement')
    plt.xticks(rotation='vertical')

    # Function to format y-axis as percentages
    def percentage_formatter(x, pos):
        return f'{100 * x:.1f}%'

    # Apply percentage formatting to the y-axis
    ax.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

    # Show the chart
    plt.legend()
    plt.show()

# %%
D1_MLP = [0.0130, 0.0136, 0.0441, 0.0223, 0.0301, 0.0486, 0.0316, 0.0512, 0.0817, 0.0584, 0.0805, 0.0991]
D1_MLP_MSE = [0.22456854,0.208308932,0.448410547,0.230470829,0.309956671,0.436168196,0.298882676,0.455159576,0.526883422,0.433514716,0.556664307,0.575951095]

plot(D1_MLP)
plot(D1_MLP_MSE)

# %%
D2_MLP = [0.0061,0.0075,0.0165,0.0072,0.0182,0.0449,0.0121,0.0383,0.0835,0.0349,0.0805,0.1338]
plot(D2_MLP)

# %%
D3_MLP = [0.0015,0.0030,0.0064,0.0031,0.0070,0.0143,0.0055,0.0204,0.0302,0.0131,0.0356,0.0383]
plot(D3_MLP)

# %%
D1_LSTM = [0.0058,0.0162,0.0183,0.0176,0.0179,0.0291,0.0168,0.0404,0.0628,0.0402,0.0641,0.3358]
plot(D1_,LSTM)

# %%
D2_LSTM = [0.0064,0.0107,0.0403,0.0159,0.0366,0.1017,0.0349,0.0997,0.3229,0.0956,0.3074,0.5022]
plot(D2_LSTM)

# %%
D1_XGB =[0.0206,0.0469,0.0734,0.0420,0.0682,0.0989,0.0681,0.0904,0.1405,0.0666,0.1226,0.2116]
plot(D1_XGB)

# %%
D2_XGB = [0.0030,0.0050,0.0169,0.0021,0.0107,0.0171,0.0010,0.0190,0.0404,0.0056,0.0337,0.0570]
plot(D2_XGB)

# %%
D3_XGB= [0.0037,0.0052,0.0115,0.0038,0.0071,0.0147,0.0063,0.0175,0.0295,0.0100,0.0365,0.0559]
plot(D3_XGB)

# %%
def plot_D1(D1_MLP, D1_MLP_MSE):
    # Labels for the x-axis
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

    bar_width = 0.6  # Width of each bar
    gap_width = 0.2  # Width of the gap between groups of bars

    # Calculate the x-positions for each group of bars
    x_positions = np.arange(len(labels))
    group_colors =  ['tab:red', 'tab:cyan','tab:orange','tab:green']
    # Plot the bars for each group
    for i in range(0, len(D1_MLP), 3):
        if i == 0:
            label = '2 Clients'
            colour = 'tab:red'
        if i == 3:
            label = '3 Clients'
            colour = 'tab:cyan'
        if i == 6:
            label = '5 Clients'
            colour = 'tab:orange'
        if i ==9:
            label = '10 Clients'
            colour = 'tab:green'
        ax1.bar(x_positions[i:i + 3], D1_MLP[i:i + 3], width=bar_width, label=label, color=colour)
        ax2.bar(x_positions[i:i + 3], D1_MLP_MSE[i:i + 3], width=bar_width, label=label, color=colour)

    ax1.set_xticks(x_positions)
    ax1.set_xticklabels(labels,rotation='vertical')
    ax2.set_xticks(x_positions)
    ax2.set_xticklabels(labels,rotation='vertical')
    ax1.set_title("(a) AUC")
    ax2.set_title("(b) MSE")
    ax1.legend()
    ax2.legend()

    ax1.set_xlabel('Data Distribution')
    ax1.set_ylabel('Performance Improvement')
    ax2.set_xlabel('Data Distribution')
    ax2.set_ylabel('Performance Improvement')

    def percentage_formatter(x, pos):
        return f'{100 * x:.1f}%'

    # Apply percentage formatting to the y-axis
    ax1.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))
    ax2.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

    plt.show()

# %%
D1_MLP = [0.0130, 0.0136, 0.0441, 0.0223, 0.0301, 0.0486, 0.0316, 0.0512, 0.0817, 0.0584, 0.0805, 0.0991]
D1_MLP_MSE = [0.159084484,0.269320787,0.4121298,0.203710061,0.327044361,0.398533486,0.319661018,0.465414516,0.496135444,0.458820646,0.541942456,0.596524489]
plot_D1(D1_MLP, D1_MLP_MSE)

# %%
D1_LSTM_MSE =[0.441895218,0.711590043,0.71679253,0.569088405,0.734469335,0.758152316,0.620023145,0.798412876,0.816568091,0.619437153,0.775295802,0.917002822]
plot_D1(D2_MLP, D1_LSTM_MSE)

# %%
D1_XGB_MSE =[0.365415336,0.427777571,0.519578591,
0.396470336,0.519671785,0.629749056,0.477494576,
0.551664862,0.741820125,0.535444466,0.710545049,0.790878992]
plot_D1(D2_MLP, D1_XGB_MSE)

# %%
central_d1_mlp_MSE = [1.9765]
dominant_d1_mlp_MSE = [2.5490,2.2260,2.0689,2.7398,2.2366,2.0238,3.2373,2.2894,2.0674,4.0626,2.3467,2.0685]
non_dominant_d1_mlp_MSE =[2.5490,2.7074,3.5865,2.7398,3.1617,3.7736,3.2373,4.0424,4.5676,4.0626,4.9593,5.3570]

fl_d1_mlp_MSE =[2.1435,1.9783,2.1084,2.1817,2.1277,2.2697,2.2024,2.1610,2.3014,2.1986,2.2716,2.1614]

central_d1_lstm_MSE = [0.8609]
dominant_d1_lstm_MSE =[1.0064,0.7527,0.6672,1.3035,0.8137,0.7450,1.5019,0.8259,0.6848,1.7470,0.7568,0.6882]
non_dominant_d1_lstm_MSE =[1.0064,1.9092,1.9480,1.3035,2.1785,2.3546,1.5019,2.8796,3.1410,1.7470,2.7321,6.6200]
fl_d1_lstm_MSE =[0.5617,0.5506,0.5517,0.5617,0.5784,0.5695,0.5707,0.5805,0.5762,0.6648,0.6139,0.5494,]

central_d1_xgb_MSE = [1.9109]
dominant_d1_xgb_MSE =[2.6536,2.4610,2.1033,3.1959,2.3660,2.1461,4.0029,2.3401,2.1170,5.0851,2.3741,2.0355]
non_dominant_d1_xgb_MSE =[2.6536,3.0601,3.8706,3.1959,3.8887,4.8726,4.0029,5.0567,7.9649,5.0851,7.7057,11.0488]
fl_d1_xgb_MSE =[1.6839,1.7511,1.8595,1.9288,1.8678,1.8041,2.0915,2.2671,2.0564,2.3623,2.2304,2.3105,]

# %%
central_d1_mlp = [0.9066]
dominant_d1_mlp = [0.8770, 0.8856, 0.8979,0.8673, 0.8789, 0.8986,0.8544, 0.8777, 0.8944,0.8270, 0.8858, 0.8926]
non_dominant_d1_mlp = [0.8770, 0.8804,0.8471,0.8673, 0.8637,0.8421,0.8544, 0.8383,0.8216,0.8270, 0.8139,0.8015,]
fl_d1_mlp = [0.8884, 0.8924,0.8844,0.8866, 0.8897,0.8831,0.8814, 0.8812,0.8887,0.8753, 0.8794,0.8809,]

central_d1_lstm = [0.9714]
dominant_d1_lstm = [0.9713, 0.9664, 0.9756,0.9600, 0.9656, 0.9735,0.9510, 0.9631, 0.9747,0.9393, 0.9680, 0.9710]
non_dominant_d1_lstm = [0.9713, 0.9634,0.9625,0.9600, 0.9566,0.9483,0.9510, 0.9389,0.9192,0.9393, 0.9173,0.7329,]
fl_d1_lstm = [0.9769, 0.9790, 0.9801,0.9769, 0.9737,0.9759,0.9758, 0.9767,0.9769,0.9770, 0.9760,0.9790,]

central_d1_xgb = [0.9154]
dominant_d1_xgb =[0.8902, 0.8999, 0.9092, 0.8702, 0.8912, 0.908, 0.8501, 0.8962, 0.9076, 0.8249, 0.9025, 0.9109]
non_dominant_d1_xgb =[0.8902, 0.8757, 0.848, 0.8702, 0.8515, 0.8266, 0.8501, 0.827, 0.7812, 0.8249, 0.785, 0.7342]
fl_d1_xgb =[0.8884, 0.8924, 0.8844, 0.9068, 0.9095, 0.9084, 0.9079, 0.9018, 0.8909, 0.8799, 0.8813, 0.8896]

# %%
def plot_performance(central, dominant, non_dominant, fl,
                     central_auc, dominant_auc, non_dominant_auc, fl_auc):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    labels = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]


    ax1.plot(labels, central_auc*12, label='Centralised', color='tab:blue')
    ax1.plot(labels, dominant_auc, label='Local Dominant', color='tab:green')
    ax1.plot(labels, non_dominant_auc, label='Local Non-Dominant', color='tab:red')
    ax1.plot(labels, fl_auc, label='Federated', color='tab:orange')

    ax2.plot(labels, central*12, label='Centralised', color='tab:blue')
    ax2.plot(labels, dominant, label='Local Dominant', color='tab:green')
    ax2.plot(labels, non_dominant, label='Local Non-Dominant', color='tab:red')
    ax2.plot(labels, fl, label='Federated', color='tab:orange')


    ax1.set_xlabel('Data Distribution')
    ax1.set_ylabel('AUC')
    ax2.set_xlabel('Data Distribution')
    ax2.set_ylabel('MSE')

    ax1.set_xticklabels(labels,rotation='vertical')
    ax2.set_xticklabels(labels,rotation='vertical')
    ax1.set_title("(a) AUC")
    ax2.set_title("(b) MSE")
    ax1.legend()
    ax2.legend()

    plt.show()

# %%
plot_performance(central_d1_xgb_MSE, dominant_d1_xgb_MSE, non_dominant_d1_xgb_MSE, fl_d1_xgb_MSE,
                 central_d1_xgb, dominant_d1_xgb, non_dominant_d1_xgb, fl_d1_xgb,)
# Out:
# C:\Users\Shuyao\AppData\Local\Temp\ipykernel_19888\670619032.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation='vertical')
# C:\Users\Shuyao\AppData\Local\Temp\ipykernel_19888\670619032.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation='vertical')

# %%
plot_performance(central_d1_lstm_MSE, dominant_d1_lstm_MSE, non_dominant_d1_lstm_MSE, fl_d1_lstm_MSE,
                 central_d1_lstm, dominant_d1_lstm, non_dominant_d1_lstm, fl_d1_lstm,)
# Out:
# C:\Users\Shuyao\AppData\Local\Temp\ipykernel_19888\670619032.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation='vertical')
# C:\Users\Shuyao\AppData\Local\Temp\ipykernel_19888\670619032.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation='vertical')

# %%
plot_performance(central_d1_lstm_MSE, dominant_d1_lstm_MSE, non_dominant_d1_lstm_MSE, fl_d1_lstm_MSE,
                 central_d1_lstm, dominant_d1_lstm, non_dominant_d1_lstm, fl_d1_lstm,)
# Out:
# C:\Users\Shuyao\AppData\Local\Temp\ipykernel_19888\670619032.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,rotation='vertical')
# C:\Users\Shuyao\AppData\Local\Temp\ipykernel_19888\670619032.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(labels,rotation='vertical')
