# %%
import matplotlib.pyplot as plt
import np as np

# %%
import torch
import matplotlib.cm as cm
import numpy as np

select = (0.1, 0.5, 0.3)
cmap = cm.Set3
colors = cmap(np.linspace(0, 1.5, 3))

y = torch.load('./dataset2/y_mlp.pt')

class_counts = y.value_counts()
class_percentages = (class_counts / class_counts.sum()) * 100
X_labels = ['Non-default', 'Default']
# Plot the distribution using a bar plot
ax = class_counts.plot(kind='bar', xlabel='Class', ylabel='Frequency', title='Class Distribution',color=colors)
plt.xticks(range(len(X_labels)), X_labels, rotation=0)  # Optional: rotate x-axis labels if needed

plt.ylim(0, 350000)
# Display percentages on top of each bar
for i, v in enumerate(class_percentages):
    ax.text(i, class_counts[i] + 10, f'{v:.2f}%', ha='center', va='bottom', color='black', fontsize=10)
plt.grid(False)
plt.show()

# %%
import pandas as pd

select = (0.1, 0.5, 0.3)
cmap = cm.Set3
colors = cmap(np.linspace(0, 1.5, 3))

y = torch.load('./dataset3/y.pt')
import torch
import matplotlib.pyplot as plt

# Assuming 'y' is your binary classification target tensor (PyTorch tensor)
# Convert 'y' to a NumPy array and flatten it
y_numpy = y.cpu().numpy().flatten()

# Round the values and convert to integers
y_rounded = np.round(y_numpy).astype(int)

# Count the occurrences of each class using NumPy
class_counts = torch.bincount(torch.from_numpy(y_rounded))
class_percentages = (class_counts / class_counts.sum()) * 100

# Create a list of class labels (assuming binary classification, 0 and 1)
class_labels = [0, 1]

# Plot the distribution using a bar plot
plt.bar(class_labels, class_counts, tick_label=class_labels,color=colors)

plt.xlabel('Class')
plt.ylabel('Frequency')
plt.title('Clss Distribution')
plt.grid(False)

for i, v in enumerate(class_percentages):
    plt.text(i, class_counts[i] + 10, f'{v:.2f}%', ha='center', va='bottom', color='black', fontsize=10)
plt.ylim(0, 160000)
plt.show()

# %%
MLP_50_50=[(1, 0.21264789998531342), (2, 0.20469626784324646), (3, 0.20167231559753418), (4, 0.19934159517288208), (5, 0.20020543038845062), (6, 0.1985892653465271), (7, 0.19811365008354187), (8, 0.19738562405109406), (9, 0.1976688951253891), (10, 0.19732984900474548), (11, 0.19633086025714874), (12, 0.19616657495498657), (13, 0.1968826949596405), (14, 0.19637349247932434), (15, 0.19760634005069733), (16, 0.19632773101329803), (17, 0.19700972735881805), (18, 0.19847777485847473), (19, 0.1949663907289505), (20, 0.1956903338432312), (21, 0.1952711045742035), (22, 0.19428500533103943), (23, 0.1960931122303009), (24, 0.19561509788036346), (25, 0.19590094685554504)]
MLP_60_40 = [(1, 0.21843409538269043), (2, 0.20503613352775574), (3, 0.20014217495918274), (4, 0.20163114368915558), (5, 0.19951100647449493), (6, 0.19998368620872498), (7, 0.1987105906009674), (8, 0.19962665438652039), (9, 0.19818896055221558), (10, 0.19789375364780426), (11, 0.19671043753623962), (12, 0.19485190510749817), (13, 0.1938886195421219), (14, 0.1964036077260971), (15, 0.19531501829624176), (16, 0.19647499918937683), (17, 0.1960705667734146), (18, 0.1948298066854477), (19, 0.19435693323612213), (20, 0.19351127743721008), (21, 0.19499942660331726), (22, 0.1946839690208435), (23, 0.19535532593727112), (24, 0.19393500685691833), (25, 0.19464674592018127)]
MLP_80_10clients = [(1, 0.21046647429466248), (2, 0.20405693352222443), (3, 0.19925129413604736), (4, 0.20008715987205505), (5, 0.20019109547138214), (6, 0.20039187371730804), (7, 0.19767464697360992), (8, 0.196367084980011), (9, 0.2012336105108261), (10, 0.19961166381835938), (11, 0.19827638566493988), (12, 0.19694314897060394), (13, 0.1946459412574768), (14, 0.19735732674598694), (15, 0.19792796671390533), (16, 0.1970977485179901), (17, 0.19826658070087433), (18, 0.1944005787372589), (19, 0.19332990050315857), (20, 0.1965285688638687), (21, 0.1971183717250824), (22, 0.19417281448841095), (23, 0.19778898358345032), (24, 0.19690564274787903), (25, 0.1920037716627121)]

# %%
x_values1, y_values1 = zip(*MLP_50_50)
x_values2, y_values2 = zip(*MLP_60_40)
x_values3, y_values3 = zip(*MLP_80_20)

x_values4, y_values4 = zip(*MLP_34_33_33)
x_values5, y_values5 = zip(*MLP_60_20_20)
x_values6, y_values6 = zip(*MLP_80_10_10)

x_values7, y_values7 = zip(*MLP_20_20_20_20_20)
x_values8, y_values8 = zip(*MLP_60_10_10_10_10)
x_values9, y_values9 = zip(*MLP_80_5_5_5_5)

x_values10, y_values10 = zip(*MLP_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*MLP_60_10clients)
x_values12, y_values12 = zip(*MLP_80_10clients)

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(0.19,0.27)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(0.19,0.27)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(0.19,0.27)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0.19,0.27)
plt.show()

# %%
XGB_50_50=[(0, 0.2610353), (1, 0.14217865), (2, 0.0857276), (3, 0.06934619), (4, 0.06875731), (5, 0.0721352), (6, 0.07168689), (7, 0.068326786), (8, 0.071426615), (9, 0.067616954), (10, 0.071037106), (11, 0.06802469), (12, 0.079511106), (13, 0.067881726), (14, 0.077629685), (15, 0.06791877), (16, 0.069657534), (17, 0.06915405), (18, 0.06981091), (19, 0.06785295), (20, 0.069236144)]
XGB_60_40 =[(0, 0.24930613), (1, 0.1463423), (2, 0.08719831), (3, 0.06920884), (4, 0.07213342), (5, 0.06882654), (6, 0.06858256), (7, 0.06842267), (8, 0.06876147), (9, 0.06816857), (10, 0.07286921), (11, 0.06851766), (12, 0.0736646), (13, 0.068743564), (14, 0.06957713), (15, 0.06917239), (16, 0.06927203), (17, 0.06865688), (18, 0.06899751), (19, 0.069032), (20, 0.069176055)]
XGB_80_20 =[(0, 0.23488827), (1, 0.12301587), (2, 0.07434467), (3, 0.069831595), (4, 0.09230213), (5, 0.06857791), (6, 0.072389446), (7, 0.06804809), (8, 0.07217935), (9, 0.068088695), (10, 0.06985363), (11, 0.068143986), (12, 0.07094616), (13, 0.06931564), (14, 0.07116316), (15, 0.0689432), (16, 0.06984701), (17, 0.06979727), (18, 0.069758475), (19, 0.06868079), (20, 0.06859586)]

XGB_34_33_33 =[(0, 0.2456199), (1, 0.12215204), (2, 0.07049362), (3, 0.072569616), (4, 0.07071366), (5, 0.07260463), (6, 0.07076552), (7, 0.072503224), (8, 0.06979667), (9, 0.06916085), (10, 0.06833006), (11, 0.068688124), (12, 0.07757463), (13, 0.069254965), (14, 0.070816025), (15, 0.067895755), (16, 0.08885178), (17, 0.068235494), (18, 0.071430944), (19, 0.07042208), (20, 0.07055107)]
XGB_60_20_20 =[(0, 0.2952379), (1, 0.15832606), (2, 0.085715525), (3, 0.06920325), (4, 0.07381834), (5, 0.06956211), (6, 0.07236407), (7, 0.06835936), (8, 0.09708681), (9, 0.06817416), (10, 0.08051545), (11, 0.06860958), (12, 0.0802231), (13, 0.06846527), (14, 0.080510415), (15, 0.06842185), (16, 0.07145877), (17, 0.068244405), (18, 0.07665933), (19, 0.06810876), (20, 0.06807328)]
# %%
x_values1, y_values1 = zip(*XGB_50_50)
x_values2, y_values2 = zip(*XGB_60_40)
x_values3, y_values3 = zip(*XGB_80_20)

x_values4, y_values4 = zip(*XGB_34_33_33)
x_values5, y_values5 = zip(*XGB_60_20_20)
x_values6, y_values6 = zip(*XGB_80_10_10)

x_values7, y_values7 = zip(*XGB_20_20_20_20_20)
x_values8, y_values8 = zip(*XGB_60_10_10_10_10)
x_values9, y_values9 = zip(*XGB_80_5_5_5_5)

x_values10, y_values10 = zip(*XGB_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*XGB_60_10clients)
x_values12, y_values12 = zip(*XGB_80_10clients)

# %%
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(0.06,0.3)
ax1.set_xticks(np.arange(0, 21, 2))

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(0.06,0.3)
ax2.set_xticks(np.arange(0, 21, 2))

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(0.06,0.3)
ax3.set_xticks(np.arange(0, 21, 2))

ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0.06,0.3)
ax4.set_xticks(np.arange(0, 21, 2))
plt.show()

# %%
# MLP
central = 0.7577
classes_2 = ["50-50", "60-40", "80-20"]
dominant_2 = [0.7540,	0.7557,	0.7566,]
non_dominant_2 = [0.7540,	0.7522,	0.7449]
fl_2 = [0.7586,	0.7579,	0.7572]

classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
dominant_3 = [0.7517,	0.7557,	0.7571]
non_dominant_3 = [0.7517,	0.7443,	0.7257	]
fl_3 = [0.7571,	0.7579,0.7583,]

classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
dominant_5 = [0.7459,	0.7554,	0.7574]
non_dominant_5 = [0.7459,	0.7280,	0.6981]
fl_5 = [0.7549,	0.7559,0.7564,]

classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
dominant_10 = [0.7270,	0.7559,	0.7565]
non_dominant_10 = [0.7270,	0.6995,	0.6681]
fl_10 = [0.7524,	0.7558,	0.7575]

classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))
plt.plot(classes, local_dominant, label='Local Dominant', color= 'tab:cyan')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant',color= 'tab:orange')
plt.plot(classes, auc_fl, label='Federated',color= 'tab:green')
plt.plot(classes, auc_central, label='Centralised',color= 'tab:red')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 2 MLP')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# %%
LSTM_50_50=[(1, 0.07216276973485947), (2, 0.07006540894508362), (3, 0.0692012831568718), (4, 0.06876661628484726), (5, 0.06853393465280533), (6, 0.06840626150369644), (7, 0.06833601742982864), (8, 0.06828977167606354), (9, 0.06825575232505798), (10, 0.06823355704545975), (11, 0.06819059699773788), (12, 0.06819534301757812), (13, 0.06817465275526047), (14, 0.06818847358226776), (15, 0.06823848932981491), (16, 0.06826134026050568), (17, 0.068146251142025), (18, 0.06814038753509521), (19, 0.06823202967643738), (20, 0.06818437576293945), (21, 0.06835038214921951), (22, 0.0682244822382927), (23, 0.06814859062433243), (24, 0.06825900822877884), (25, 0.0682329535484314), (26, 0.06835753470659256), (27, 0.06816542893648148), (28, 0.06823750585317612), (29, 0.06808986514806747), (30, 0.06823012232780457), (31, 0.06816652417182922), (32, 0.0681132823228836), (33, 0.06815578788518906), (34, 0.06835833936929703), (35, 0.06811896711587906), (36, 0.06830620020627975), (37, 0.06817133724689484), (38, 0.06812994927167892), (39, 0.0681389793753624), (40, 0.06812422722578049)]
LSTM_60_10clients =[(1, 0.2299295961856842), (2, 0.2096557915210724), (3, 0.18597006797790527), (4, 0.15880970656871796), (5, 0.11209596693515778), (6, 0.08362726867198944), (7, 0.07500011473894119), (8, 0.07256685197353363), (9, 0.07157354056835175), (10, 0.07095933705568314), (11, 0.07049066573381424), (12, 0.0701209157705307), (13, 0.07002446800470352), (14, 0.06993922591209412), (15, 0.06969166547060013), (16, 0.06961087882518768), (17, 0.06941428035497665), (18, 0.06923795491456985), (19, 0.06919562071561813), (20, 0.06915198266506195), (21, 0.0690268725156784), (22, 0.06892761588096619), (23, 0.06889862567186356), (24, 0.06881289184093475), (25, 0.06877686828374863), (26, 0.06870370358228683), (27, 0.06868268549442291), (28, 0.06863006949424744), (29, 0.06860841065645218), (30, 0.06857719272375107), (31, 0.06853555887937546), (32, 0.06850626319646835), (33, 0.06854945421218872), (34, 0.0684332475066185), (35, 0.06842741370201111), (36, 0.06839855015277863), (37, 0.0683879554271698), (38, 0.06837256252765656), (39, 0.06835158914327621), (40, 0.06834125518798828)]
LSTM_80_10clients =[(1, 0.23366670310497284), (2, 0.22307738661766052), (3, 0.2113582342863083), (4, 0.198531374335289), (5, 0.18456046283245087), (6, 0.14403505623340607), (7, 0.12801337242126465), (8, 0.09837768971920013), (9, 0.08115013688802719), (10, 0.07584723830223083), (11, 0.07200521230697632), (12, 0.07135224342346191), (13, 0.07068247348070145), (14, 0.07024654000997543), (15, 0.07018323242664337), (16, 0.06985524296760559), (17, 0.06958910822868347), (18, 0.06936927139759064), (19, 0.06919311732053757), (20, 0.06904269009828568), (21, 0.06902405619621277), (22, 0.06890615075826645), (23, 0.06889668107032776), (24, 0.06888719648122787), (25, 0.06886691600084305), (26, 0.06876739859580994), (27, 0.06875190138816833), (28, 0.06867316365242004), (29, 0.06860683858394623), (30, 0.06855123490095139), (31, 0.06853631138801575), (32, 0.06852681934833527), (33, 0.06852398812770844), (34, 0.06850183755159378), (35, 0.0684589371085167), (36, 0.06843731552362442), (37, 0.0684090182185173), (38, 0.06843974441289902), (39, 0.06841354072093964), (40, 0.06843580305576324)]

# %%
x_values1, y_values1 = zip(*LSTM_50_50)
x_values2, y_values2 = zip(*LSTM_60_40)
x_values3, y_values3 = zip(*LSTM_80_20)

x_values4, y_values4 = zip(*LSTM_34_33_33)
x_values5, y_values5 = zip(*LSTM_60_20_20)
x_values6, y_values6 = zip(*LSTM_80_10_10)

x_values7, y_values7 = zip(*LSTM_20_20_20_20_20)
x_values8, y_values8 = zip(*LSTM_60_10_10_10_10)
x_values9, y_values9 = zip(*LSTM_80_5_5_5_5)

x_values10, y_values10 = zip(*LSTM_10_10_10_10_10_10_10_10_10_10)
x_values11, y_values11 = zip(*LSTM_60_10clients)
x_values12, y_values12 = zip(*LSTM_80_10clients)

# %%
#LSTM
plt.figure(figsize=(40, 20))
fig, ax = plt.subplots(2, 2,figsize=(12, 8))
plt.tight_layout(w_pad=4, h_pad=4)


ax1 = ax[0, 0]
ax2 = ax[0, 1]
ax3 = ax[1, 0]
ax4 = ax[1, 1]

ax1.plot(x_values1, y_values1, marker='.', linestyle='-',color='tab:orange', label='50-50')
ax1.plot(x_values2, y_values2, marker='.', linestyle='-',color='tab:green', label='60-40')
ax1.plot(x_values3, y_values3, marker='.', linestyle='-',color='tab:cyan',label='80-20')
ax1.set_title("(a) 2 Clients")
ax1.set_xlabel('Number of Rounds')
ax1.set_ylabel('MSE Loss')
ax1.legend()
ax1.set_ylim(0.068,0.075)

ax2.plot(x_values4, y_values4, marker='.', linestyle='-',color='tab:orange', label='34-33-33')
ax2.plot(x_values5, y_values5, marker='.', linestyle='-', color='tab:green', label='60-20-20')
ax2.plot(x_values6, y_values6, marker='.', linestyle='-', color='tab:cyan',label='80-10-10')
ax2.set_title("(b) 3 Clients")
ax2.set_xlabel('Number of Rounds')
ax2.set_ylabel('MSE Loss')
ax2.legend()
ax2.set_ylim(0.068,0.075)

ax3.plot(x_values7, y_values7, marker='.', linestyle='-', color='tab:orange',label='20-20-20-20-20')
ax3.plot(x_values8, y_values8, marker='.', linestyle='-', color='tab:green', label='60-10-10-10-10')
ax3.plot(x_values9, y_values9, marker='.', linestyle='-', color='tab:cyan',label='80-5-5-5-5')
ax3.set_title("(c) 5 Clients")
ax3.set_xlabel('Number of Rounds')
ax3.set_ylabel('MSE Loss')
ax3.legend()
ax3.set_ylim(0.068,0.075)


ax4.plot(x_values10, y_values10, marker='.', linestyle='-', color='tab:orange',label='10-10-10-10-10-10-10-10-10-10')
ax4.plot(x_values11, y_values11, marker='.', linestyle='-', color='tab:green', label='60-5-5-5-5-4-4-4-4-4')
ax4.plot(x_values12, y_values12, marker='.', linestyle='-', color='tab:cyan',label='80-3-3-2-2-2-2-2-2-2')
ax4.set_title("(d) 10 Clients")
ax4.set_xlabel('Number of Rounds')
ax4.set_ylabel('MSE Loss')
ax4.legend()
ax4.set_ylim(0.068,0.075)
plt.show()

# %%
#LSTM
central = 0.7503
classes_2 = ["50-50", "60-40", "80-20"]
dominant_2 = [0.7466,	0.7484,	0.7505,]
non_dominant_2 = [0.7466, 0.7442,	0.7227]
fl_2 = [0.7513,	0.7522,	0.7518]

classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
dominant_3 = [0.7392,	0.7481,	0.7504]
non_dominant_3 = [0.7392,	0.7242,	0.6805]
fl_3 = [0.7510,0.7508,0.7498,]

classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
dominant_5 = [0.7238,	0.7489,	0.7504]
non_dominant_5 = [0.7238,	0.6830,	0.5675]
fl_5 = [0.7491,0.7511,0.7507,]

classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
dominant_10 = [0.6843,	0.7484,	0.7504]
non_dominant_10 = [0.6843,	0.5728,	0.4995]
fl_10 = [0.7494,0.7489,0.7504,]

classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))
plt.plot(classes, local_dominant, label='Local Dominant', color= 'tab:cyan')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant',color= 'tab:orange')
plt.plot(classes, auc_fl, label='Federated',color= 'tab:green')
plt.plot(classes, auc_central, label='Centralised',color= 'tab:red')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 2 LSTM')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# %%
import numpy as np
# XGB
central = 0.7667

classes_2 = ["50-50", "60-40", "80-20"]
dominant_2 = [0.7617, 0.7629, 0.7646]
non_dominant_2 = [0.7617, 0.7612, 0.7532]
fl_2 = [0.7640, 0.7650, 0.7659]

classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
dominant_3 = [0.7581, 0.7629, 0.7646]
non_dominant_3 = [0.7581,0.7534,0.7416,]
fl_3 = [0.7597, 0.7615, 0.7543]

classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
dominant_5 = [0.7522, 0.7633, 0.7650]
non_dominant_5 = [0.7522,0.7412,0.7206,]
fl_5 = [0.7530, 0.7553, 0.7497]

classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
dominant_10 = [0.7413, 0.7633, 0.7650]
non_dominant_10 = [0.7413,0.7204,0.7046,]
fl_10 = [0.7454, 0.7446, 0.7448]

classes = ["50-50", "60-40", "80-20","34-33-33", "60-20-20", "80-10-10","20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5","10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]

local_dominant = dominant_2 + dominant_3 + dominant_5 + dominant_10

locan_non_dominant = non_dominant_2 +non_dominant_3 + non_dominant_5 + non_dominant_10

auc_fl = fl_2 + fl_3 + fl_5 + fl_10
auc_central = 12 * [central]

plt.figure(figsize=(10, 6))
plt.plot(classes, local_dominant, label='Local Dominant', color= 'tab:cyan')
plt.plot(classes, locan_non_dominant, label='Local Non-Dominant',color= 'tab:orange')
plt.plot(classes, auc_fl, label='Federated',color= 'tab:green')
plt.plot(classes, auc_central, label='Centralised',color= 'tab:red')

plt.xlabel('Data Distribution')
plt.ylabel('Auc')
#plt.title('Dateset 2 XGB')
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# plt.figure(figsize=(40, 20))
# fig, ax = plt.subplots(2, 2,figsize=(12, 8))
# plt.tight_layout(w_pad=4, h_pad=4)
#
#
# ax1 = ax[0, 0]
# ax2 = ax[0, 1]
# ax3 = ax[1, 0]
# ax4 = ax[1, 1]
#
#
# xticks = np.arange(len(classes_2))
#
# ax1.bar(xticks, dominant_2, width=0.25, color='tab:orange',label="Local Dominant")
# ax1.bar(xticks + 0.25, non_dominant_2,width=0.25, color='tab:green',label="Local Non-dominant")
# ax1.bar(xticks + 0.5, fl_2,width=0.25, color='tab:cyan',label="Federated Learning")
# ax1.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax1.set_title("(a) 2 Clients")
# ax1.set_xlabel("Data Distribution")
# ax1.set_ylabel("AUC")
# ax1.legend(loc='upper left', fontsize=7)
# ax1.set_ylim(0.68, 0.8)
# ax1.set_xticks(xticks + 0.25)
# ax1.set_xticklabels(classes_2)
#
# ax2.bar(xticks, dominant_3, width=0.25, color='tab:orange',label="Local Dominant")
# ax2.bar(xticks + 0.25, non_dominant_3,width=0.25, color='tab:green',label="Local Non-dominant")
# ax2.bar(xticks + 0.5, fl_3,width=0.25, color='tab:cyan',label="Federated Learning")
# ax2.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax2.set_title("(b) 3 Clients")
# ax2.set_xlabel('Data Distribution')
# ax2.set_ylabel('AUC')
# ax2.legend(loc='upper left', fontsize=7)
# ax2.set_ylim(0.68, 0.8)
# ax2.set_xticks(xticks + 0.25)
# ax2.set_xticklabels(classes_3)
#
# ax3.bar(xticks, dominant_5, width=0.25, color='tab:orange',label="Local Dominant")
# ax3.bar(xticks + 0.25, non_dominant_5,width=0.25, color='tab:green',label="Local Non-dominant")
# ax3.bar(xticks + 0.5, fl_5,width=0.25, color='tab:cyan',label="Federated Learning")
# ax3.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax3.set_title("(c) 5 Clients")
# ax3.set_xlabel('Data Distribution')
# ax3.set_ylabel('AUC')
# ax3.legend(loc='upper left', fontsize=7)
# ax3.set_ylim(0.68, 0.8)
# ax3.set_xticks(xticks + 0.25)
# ax3.set_xticklabels(classes_5)
#
# ax4.bar(xticks, dominant_10, width=0.25, color='tab:orange',label="Local Dominant")
# ax4.bar(xticks + 0.25, non_dominant_10,width=0.25, color='tab:green',label="Local Non-dominant")
# ax4.bar(xticks + 0.5, fl_10,width=0.25, color='tab:cyan',label="Federated Learning")
# ax4.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax4.set_title("(d) 10 Clients")
# ax4.set_xlabel('Data Distribution')
# ax4.set_ylabel('AUC')
# ax4.legend(loc='upper left', fontsize=7)
# ax4.set_ylim(0.68, 0.8)
# ax4.set_xticks(xticks + 0.25)
# ax4.set_xticklabels(classes_10)
# plt.show()

# %%
# import numpy as np
#
# central = 0.7564
# classes_2 = ["50-50", "60-40", "80-20"]
# dominant_2 = [0.7541,	0.7557,	0.7566,]
# non_dominant_2 = [0.7539,	0.7522,	0.7449]
# fl_2 = [0.7540,	0.7579,	0.7572]
#
# classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
# dominant_3 = [0.7519,	0.7557,	0.7571]
# non_dominant_3 = [0.7515,	0.7443,	0.7257	]
# fl_3 = [0.7571,	0.7579,0.7583,]
#
# classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
# dominant_5 = [0.7571,	0.7554,	0.7574]
# non_dominant_5 = [0.7257,	0.7280,	0.6981]
# fl_5 = [0.7549,	0.7559,0.7564,]
#
# classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
# dominant_10 = [0.7254,	0.7559,	0.7565]
# non_dominant_10 = [0.7286,	0.6995,	0.6681]
# fl_10 = [0.7524,	0.7558,	0.7575]
#
# plt.figure(figsize=(40, 20))
# fig, ax = plt.subplots(2, 2,figsize=(12, 8))
# plt.tight_layout(w_pad=4, h_pad=4)
#
#
# ax1 = ax[0, 0]
# ax2 = ax[0, 1]
# ax3 = ax[1, 0]
# ax4 = ax[1, 1]
#
#
# xticks = np.arange(len(classes_2))
#
# ax1.bar(xticks, dominant_2, width=0.25, color='tab:orange',label="Local Dominant")
# ax1.bar(xticks + 0.25, non_dominant_2,width=0.25, color='tab:green',label="Local Non-dominant")
# ax1.bar(xticks + 0.5, fl_2,width=0.25, color='tab:cyan',label="Federated Learning")
# ax1.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax1.set_title("(a) 2 Clients")
# ax1.set_xlabel("Data Distribution")
# ax1.set_ylabel("AUC")
# ax1.legend(loc='upper left', fontsize=7)
# ax1.set_ylim(0.64, 0.8)
# ax1.set_xticks(xticks + 0.25)
# ax1.set_xticklabels(classes_2)
#
# ax2.bar(xticks, dominant_3, width=0.25, color='tab:orange',label="Local Dominant")
# ax2.bar(xticks + 0.25, non_dominant_3,width=0.25, color='tab:green',label="Local Non-dominant")
# ax2.bar(xticks + 0.5, fl_3,width=0.25, color='tab:cyan',label="Federated Learning")
# ax2.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax2.set_title("(b) 3 Clients")
# ax2.set_xlabel('Data Distribution')
# ax2.set_ylabel('AUC')
# ax2.legend(loc='upper left', fontsize=7)
# ax2.set_ylim(0.64, 0.8)
# ax2.set_xticks(xticks + 0.25)
# ax2.set_xticklabels(classes_3)
#
# ax3.bar(xticks, dominant_5, width=0.25, color='tab:orange',label="Local Dominant")
# ax3.bar(xticks + 0.25, non_dominant_5,width=0.25, color='tab:green',label="Local Non-dominant")
# ax3.bar(xticks + 0.5, fl_5,width=0.25, color='tab:cyan',label="Federated Learning")
# ax3.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax3.set_title("(c) 5 Clients")
# ax3.set_xlabel('Data Distribution')
# ax3.set_ylabel('AUC')
# ax3.legend(loc='upper left', fontsize=7)
# ax3.set_ylim(0.64, 0.8)
# ax3.set_xticks(xticks + 0.25)
# ax3.set_xticklabels(classes_5)
#
# ax4.bar(xticks, dominant_10, width=0.25, color='tab:orange',label="Local Dominant")
# ax4.bar(xticks + 0.25, non_dominant_10,width=0.25, color='tab:green',label="Local Non-dominant")
# ax4.bar(xticks + 0.5, fl_10,width=0.25, color='tab:cyan',label="Federated Learning")
# ax4.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax4.set_title("(d) 10 Clients")
# ax4.set_xlabel('Data Distribution')
# ax4.set_ylabel('AUC')
# ax4.legend(loc='upper left', fontsize=7)
# ax4.set_ylim(0.64, 0.8)
# ax4.set_xticks(xticks + 0.25)
# ax4.set_xticklabels(classes_10)
# plt.show()

# %%
# # LSTM
# import numpy as np
#
# central = 0.7503
# classes_2 = ["50-50", "60-40", "80-20"]
# dominant_2 = [0.7466,	0.7484,	0.7505,]
# non_dominant_2 = [0.7466, 0.7442,	0.7227]
# fl_2 = [0.7496,	0.7507,	0.7504]
#
# classes_3 = ["34-33-33", "60-20-20", "80-10-10"]
# dominant_3 = [0.7339,	0.7481,	0.7504]
# non_dominant_3 = [0.7385,	0.7242,	0.6805]
# fl_3 = [0.7409,0.7412,0.7384,]
#
# classes_5 = ["20-20-20-20-20", "60-10-10-10-10", "80-5-5-5-5"]
# dominant_5 = [0.7236,	0,	0.7504]
# non_dominant_5 = [0.7240,	0,	0.5675]
# fl_5 = [0.7488,0.7488,0.7488,]
#
# classes_10 = ["10-10-10-10-10-\n10-10-10-10-10", "60-5-5-5-5-\n4-4-4-4-4", "80-3-3-2-2-\n2-2-2-2-2"]
# dominant_10 = [0.6851,	0.7484,	0.7504]
# non_dominant_10 = [0.6836,	0.5728,	0.4995]
# fl_10 = [0.7391,0.7403,0.7390,]
#
# plt.figure(figsize=(40, 20))
# fig, ax = plt.subplots(2, 2,figsize=(12, 8))
# plt.tight_layout(w_pad=4, h_pad=4)
#
#
# ax1 = ax[0, 0]
# ax2 = ax[0, 1]
# ax3 = ax[1, 0]
# ax4 = ax[1, 1]
#
#
# xticks = np.arange(len(classes_2))
#
# ax1.bar(xticks, dominant_2, width=0.25, color='tab:orange',label="Local Dominant")
# ax1.bar(xticks + 0.25, non_dominant_2,width=0.25, color='tab:green',label="Local Non-dominant")
# ax1.bar(xticks + 0.5, fl_2,width=0.25, color='tab:cyan',label="Federated Learning")
# ax1.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax1.set_title("(a) 2 Clients")
# ax1.set_xlabel("Data Distribution")
# ax1.set_ylabel("AUC")
# ax1.legend(loc='upper left', fontsize=7)
# ax1.set_ylim(0.45, 0.85)
# ax1.set_xticks(xticks + 0.25)
# ax1.set_xticklabels(classes_2)
#
# ax2.bar(xticks, dominant_3, width=0.25, color='tab:orange',label="Local Dominant")
# ax2.bar(xticks + 0.25, non_dominant_3,width=0.25, color='tab:green',label="Local Non-dominant")
# ax2.bar(xticks + 0.5, fl_3,width=0.25, color='tab:cyan',label="Federated Learning")
# ax2.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax2.set_title("(b) 3 Clients")
# ax2.set_xlabel('Data Distribution')
# ax2.set_ylabel('AUC')
# ax2.legend(loc='upper left', fontsize=7)
# ax2.set_ylim(0.45, 0.85)
# ax2.set_xticks(xticks + 0.25)
# ax2.set_xticklabels(classes_3)
#
# ax3.bar(xticks, dominant_5, width=0.25, color='tab:orange',label="Local Dominant")
# ax3.bar(xticks + 0.25, non_dominant_5,width=0.25, color='tab:green',label="Local Non-dominant")
# ax3.bar(xticks + 0.5, fl_5,width=0.25, color='tab:cyan',label="Federated Learning")
# ax3.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax3.set_title("(c) 5 Clients")
# ax3.set_xlabel('Data Distribution')
# ax3.set_ylabel('AUC')
# ax3.legend(loc='upper left', fontsize=7)
# ax3.set_ylim(0.45, 0.85)
# ax3.set_xticks(xticks + 0.25)
# ax3.set_xticklabels(classes_5)
#
# ax4.bar(xticks, dominant_10, width=0.25, color='tab:orange',label="Local Dominant")
# ax4.bar(xticks + 0.25, non_dominant_10,width=0.25, color='tab:green',label="Local Non-dominant")
# ax4.bar(xticks + 0.5, fl_10,width=0.25, color='tab:cyan',label="Federated Learning")
# ax4.axhline(y=central, color='tab:red', linestyle='--', label='Centralised')
# ax4.set_title("(d) 10 Clients")
# ax4.set_xlabel('Data Distribution')
# ax4.set_ylabel('AUC')
# ax4.legend(loc='upper left', fontsize=7)
# ax4.set_ylim(0.45, 0.85)
# ax4.set_xticks(xticks + 0.25)
# ax4.set_xticklabels(classes_10)
# plt.show()
